# %% [markdown]
# -------------------------
# ## Compile Plots at All Timesteps for a Video

# %% [markdown]
# ### The below code is for a 3D Plot
#
# - Line #10: Change the directory of the results that will be plotted
# - Line #12: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #13: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize


# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260615_111721__nsteps=200001__mesh=colored_labels_labels"
mesh_file = os.path.join(result_dir, "pmesh_00000")
pattern = os.path.join(result_dir, "phE_[0-9]*")  # skip gif output
output_gif = os.path.join(result_dir, "phE_animation.gif")

# --- Load mesh once ---
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]

print(f"Found {len(files)} snapshots:")
# for f in files:
#     print("  ", os.path.basename(f))

# --- Setup figure once ---
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
# ax.set_title("Electrolyte Potential (phE)")
ax.view_init(elev=30, azim=45)

# norm = Normalize(vmin=0.0, vmax=1.0)
# levels = np.linspace(0, 1, 100) 

# Initialize dummy colorbar
dummy = ax.plot_trisurf(X, Y, np.zeros_like(X), cmap='viridis', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.6, pad=0.1)
dummy.remove()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load grid function
        x = mfem.GridFunction(mesh, fname)
        Z = x.GetDataArray()

        # Auto-compute color scale for this frame
        zmin, zmax = np.min(Z), np.max(Z)

        # Z = np.clip(Z, 0.0, 1.0)

        # zmin, zmax = np.min(Z), np.max(Z)

        # Redraw surface and colorbar
        ax.clear()
        # surf = ax.plot_trisurf(X, Y, Z, cmap='turbo', norm=norm)
        surf = ax.plot_trisurf(X, Y, Z, cmap='turbo')

        ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
        ax.set_title(f"Cathode Concentration (CnC) — timestep {timestep}")
        # ax.set_zlim(0.0, 1.0)
        # Update colorbar each frame
        cbar.ax.clear()
        fig.colorbar(surf, cax=cbar.ax)
        # cbar.ax.set_ylabel("Potential")

        # Save frame
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

os.remove("temp_frame.png")
print(f"✅ Animation saved to: {output_gif}")

# %% [markdown]
# ### The below code is for a 2D Contour Plot
#
# - Line #9: Change the directory of the results that will be plotted
# - Line #11: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #12: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize

# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260617_095901__nsteps=2000001__mesh=colored_labels_labels"
mesh_file = os.path.join(result_dir, "pmesh")
# mesh_file = os.path.join("../MSU_HPCC/pmesh")
pattern = os.path.join(result_dir, "CnP_total_[0-9]*")
output_gif = os.path.join(result_dir, "CnP_contour_animation.gif")

# --- Load mesh once --/
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Get vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]
# files = [f for f in files if get_timestep(f) % 1000 == 0]

print(f"Found {len(files)} snapshots:")

# --- Setup figure ---
fig, ax = plt.subplots(figsize=(7, 6))
ax.set_aspect('equal', adjustable='box')
ax.set_xticks([]); ax.set_yticks([])
plt.tight_layout()

# ✅ Fixed normalization and levels
norm = Normalize(vmin=0.0, vmax=1.0)
levels = np.linspace(0, 1.0, 100) 

# Dummy contour for fixed 0–1 colorbar
dummy = ax.tricontourf(X, Y, np.zeros_like(X), levels=levels, cmap='turbo', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.8, pad=0.02)
cbar.set_label("Lithium Concentration")
ax.clear()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load MFEM GridFunction data
        gf = mfem.GridFunction(mesh, fname)
        Z = gf.GetDataArray()

        Z = np.clip(Z, 0.0, 1.0) # Forcing values within [0, 1.0]

        ax.clear()
        cntr = ax.tricontourf(X, Y, Z, levels=levels, cmap='turbo', norm=norm)
        ax.set_aspect('equal', adjustable='box')
        ax.set_xticks([]); ax.set_yticks([])
        ax.set_title(f"Lithium Concentration — timestep {timestep}")

        # Save frame to temp file
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

# Clean up temporary frame
os.remove("temp_frame.png")
print(f"✅ 2D contour animation saved to: {output_gif}")
# Out:
# Found 388 snapshots:
# Rendering 1/388: timestep 0
# /tmp/ipykernel_1823700/76594926.py:78: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   writer.append_data(imageio.imread(frame_path))
# Rendering 2/388: timestep 5000
# Rendering 3/388: timestep 10000
# Rendering 4/388: timestep 15000
# Rendering 5/388: timestep 20000
# Rendering 6/388: timestep 25000
# Rendering 7/388: timestep 30000
# Rendering 8/388: timestep 35000
# Rendering 9/388: timestep 40000
# Rendering 10/388: timestep 45000
# Rendering 11/388: timestep 50000
# Rendering 12/388: timestep 55000
# Rendering 13/388: timestep 60000
# Rendering 14/388: timestep 65000
# Rendering 15/388: timestep 70000
# Rendering 16/388: timestep 75000
# Rendering 17/388: timestep 80000
# Rendering 18/388: timestep 85000
# Rendering 19/388: timestep 90000
# Rendering 20/388: timestep 95000
# Rendering 21/388: timestep 100000
# Rendering 22/388: timestep 105000
# Rendering 23/388: timestep 110000
# Rendering 24/388: timestep 115000
# Rendering 25/388: timestep 120000
# Rendering 26/388: timestep 125000
# Rendering 27/388: timestep 130000
# Rendering 28/388: timestep 135000
# Rendering 29/388: timestep 140000
# Rendering 30/388: timestep 145000
# Rendering 31/388: timestep 150000
# Rendering 32/388: timestep 155000
# Rendering 33/388: timestep 160000
# Rendering 34/388: timestep 165000
# Rendering 35/388: timestep 170000
# Rendering 36/388: timestep 175000
# Rendering 37/388: timestep 180000
# Rendering 38/388: timestep 185000
# Rendering 39/388: timestep 190000
# Rendering 40/388: timestep 195000
# Rendering 41/388: timestep 200000
# Rendering 42/388: timestep 205000
# Rendering 43/388: timestep 210000
# Rendering 44/388: timestep 215000
# Rendering 45/388: timestep 220000
# Rendering 46/388: timestep 225000
# Rendering 47/388: timestep 230000
# Rendering 48/388: timestep 235000
# Rendering 49/388: timestep 240000
# Rendering 50/388: timestep 245000
# Rendering 51/388: timestep 250000
# Rendering 52/388: timestep 255000
# Rendering 53/388: timestep 260000
# Rendering 54/388: timestep 265000
# Rendering 55/388: timestep 270000
# Rendering 56/388: timestep 275000
# Rendering 57/388: timestep 280000
# Rendering 58/388: timestep 285000
# Rendering 59/388: timestep 290000
# Rendering 60/388: timestep 295000
# Rendering 61/388: timestep 300000
# Rendering 62/388: timestep 305000
# Rendering 63/388: timestep 310000
# Rendering 64/388: timestep 315000
# Rendering 65/388: timestep 320000
# Rendering 66/388: timestep 325000
# Rendering 67/388: timestep 330000
# Rendering 68/388: timestep 335000
# Rendering 69/388: timestep 340000
# Rendering 70/388: timestep 345000
# Rendering 71/388: timestep 350000
# Rendering 72/388: timestep 355000
# Rendering 320/388: timestep 1595000
# Rendering 321/388: timestep 1600000
# Rendering 322/388: timestep 1605000
# Rendering 323/388: timestep 1610000
# Rendering 324/388: timestep 1615000
# Rendering 325/388: timestep 1620000
# Rendering 326/388: timestep 1625000
# Rendering 327/388: timestep 1630000
# Rendering 328/388: timestep 1635000
# Rendering 329/388: timestep 1640000
# Rendering 330/388: timestep 1645000
# Rendering 331/388: timestep 1650000
# Rendering 332/388: timestep 1655000
# Rendering 333/388: timestep 1660000
# Rendering 334/388: timestep 1665000
# Rendering 335/388: timestep 1670000
# Rendering 336/388: timestep 1675000
# Rendering 337/388: timestep 1680000
# Rendering 338/388: timestep 1685000
# Rendering 339/388: timestep 1690000
# Rendering 340/388: timestep 1695000
# Rendering 341/388: timestep 1700000
# Rendering 342/388: timestep 1705000
# Rendering 343/388: timestep 1710000
# Rendering 344/388: timestep 1715000
# Rendering 345/388: timestep 1720000
# Rendering 346/388: timestep 1725000
# Rendering 347/388: timestep 1730000
# Rendering 348/388: timestep 1735000
# Rendering 349/388: timestep 1740000
# Rendering 350/388: timestep 1745000
# Rendering 351/388: timestep 1750000
# Rendering 352/388: timestep 1755000
# Rendering 353/388: timestep 1760000
# Rendering 354/388: timestep 1765000
# Rendering 355/388: timestep 1770000
# Rendering 356/388: timestep 1775000
# Rendering 357/388: timestep 1780000
# Rendering 358/388: timestep 1785000
# Rendering 359/388: timestep 1790000
# Rendering 360/388: timestep 1795000
# Rendering 361/388: timestep 1800000
# Rendering 362/388: timestep 1805000
# Rendering 363/388: timestep 1810000
# Rendering 364/388: timestep 1815000
# Rendering 365/388: timestep 1820000
# Rendering 366/388: timestep 1825000
# Rendering 367/388: timestep 1830000
# Rendering 368/388: timestep 1835000
# Rendering 369/388: timestep 1840000
# Rendering 370/388: timestep 1845000
# Rendering 371/388: timestep 1850000
# Rendering 372/388: timestep 1855000
# Rendering 373/388: timestep 1860000
# Rendering 374/388: timestep 1865000
# Rendering 375/388: timestep 1870000
# Rendering 376/388: timestep 1875000
# Rendering 377/388: timestep 1880000
# Rendering 378/388: timestep 1885000
# Rendering 379/388: timestep 1890000
# Rendering 380/388: timestep 1895000
# Rendering 381/388: timestep 1900000
# Rendering 382/388: timestep 1905000
# Rendering 383/388: timestep 1910000
# Rendering 384/388: timestep 1915000
# Rendering 385/388: timestep 1920000
# Rendering 386/388: timestep 1925000
# Rendering 387/388: timestep 1930000
# Rendering 388/388: timestep 1935000
# ✅ 2D contour animation saved to: ../outputs/Results/20260617_095901__nsteps=2000001__mesh=colored_labels_labels/CnP_contour_animation.gif

# %% [markdown]
# To watch video on Mac (local computer):
#
#     1. Download gif file
#     2. Run         ffmpeg -i CnP_contour_animation.gif \
#                    -vf "scale=ceil(iw/2)*2:ceil(ih/2)*2" \
#                    -movflags faststart -pix_fmt yuv420p \
#                     CnP_contour_animation.mp4
