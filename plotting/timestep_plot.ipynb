# %% [markdown]
# -------------------------
# ## Compile Plots at All Timesteps for a Video

# %% [markdown]
# ### The below code is for a 3D Plot
#
# - Line #10: Change the directory of the results that will be plotted
# - Line #12: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #13: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize


# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260615_111721__nsteps=200001__mesh=colored_labels_labels"
mesh_file = os.path.join(result_dir, "pmesh_00000")
pattern = os.path.join(result_dir, "phE_[0-9]*")  # skip gif output
output_gif = os.path.join(result_dir, "phE_animation.gif")

# --- Load mesh once ---
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]

print(f"Found {len(files)} snapshots:")
# for f in files:
#     print("  ", os.path.basename(f))

# --- Setup figure once ---
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
# ax.set_title("Electrolyte Potential (phE)")
ax.view_init(elev=30, azim=45)

# norm = Normalize(vmin=0.0, vmax=1.0)
# levels = np.linspace(0, 1, 100) 

# Initialize dummy colorbar
dummy = ax.plot_trisurf(X, Y, np.zeros_like(X), cmap='viridis', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.6, pad=0.1)
dummy.remove()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load grid function
        x = mfem.GridFunction(mesh, fname)
        Z = x.GetDataArray()

        # Auto-compute color scale for this frame
        zmin, zmax = np.min(Z), np.max(Z)

        # Z = np.clip(Z, 0.0, 1.0)

        # zmin, zmax = np.min(Z), np.max(Z)

        # Redraw surface and colorbar
        ax.clear()
        # surf = ax.plot_trisurf(X, Y, Z, cmap='turbo', norm=norm)
        surf = ax.plot_trisurf(X, Y, Z, cmap='turbo')

        ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
        ax.set_title(f"Cathode Concentration (CnC) — timestep {timestep}")
        # ax.set_zlim(0.0, 1.0)
        # Update colorbar each frame
        cbar.ax.clear()
        fig.colorbar(surf, cax=cbar.ax)
        # cbar.ax.set_ylabel("Potential")

        # Save frame
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

os.remove("temp_frame.png")
print(f"✅ Animation saved to: {output_gif}")

# %% [markdown]
# ### The below code is for a 2D Contour Plot
#
# - Line #9: Change the directory of the results that will be plotted
# - Line #11: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #12: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize

# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260707_115008__nsteps=1__mesh=colored_labels_labels"
mesh_file = os.path.join(result_dir, "pmesh")
# mesh_file = os.path.join("../MSU_HPCC/pmesh")
pattern = os.path.join(result_dir, "CnP_total_[0-9]*")
output_gif = os.path.join(result_dir, "CnP_contour_animation.gif")

# --- Load mesh once --/
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Get vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]
# files = [f for f in files if get_timestep(f) % 1000 == 0]

print(f"Found {len(files)} snapshots:")

# --- Setup figure ---
fig, ax = plt.subplots(figsize=(7, 6))
ax.set_aspect('equal', adjustable='box')
ax.set_xticks([]); ax.set_yticks([])
plt.tight_layout()

# ✅ Fixed normalization and levels
norm = Normalize(vmin=0.0, vmax=0.20)
levels = np.linspace(0, 0.20, 100) 

# Dummy contour for fixed 0–1 colorbar
dummy = ax.tricontourf(X, Y, np.zeros_like(X), levels=levels, cmap='turbo', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.8, pad=0.02)
cbar.set_label("Lithium Concentration")
ax.clear()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load MFEM GridFunction data
        gf = mfem.GridFunction(mesh, fname)
        Z = gf.GetDataArray()

        Z = np.clip(Z, 0.0, 0.20) # Forcing values within [0, 1.0]

        ax.clear()
        cntr = ax.tricontourf(X, Y, Z, levels=levels, cmap='turbo', norm=norm)
        ax.set_aspect('equal', adjustable='box')
        ax.set_xticks([]); ax.set_yticks([])
        ax.set_title(f"Lithium Concentration — timestep {timestep}")

        # Save frame to temp file
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

# Clean up temporary frame
os.remove("temp_frame.png")
print(f"✅ 2D contour animation saved to: {output_gif}")
# Out:
# Found 317 snapshots:
# Rendering 1/317: timestep 0
# /tmp/ipykernel_66355/1127258857.py:78: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   writer.append_data(imageio.imread(frame_path))
# Rendering 2/317: timestep 10000
# Rendering 3/317: timestep 20000
# Rendering 4/317: timestep 30000
# Rendering 5/317: timestep 40000
# Rendering 6/317: timestep 50000
# Rendering 7/317: timestep 60000
# Rendering 8/317: timestep 70000
# Rendering 9/317: timestep 80000
# Rendering 10/317: timestep 90000
# Rendering 11/317: timestep 100000
# Rendering 12/317: timestep 110000
# Rendering 13/317: timestep 120000
# Rendering 14/317: timestep 130000
# Rendering 15/317: timestep 140000
# Rendering 16/317: timestep 150000
# Rendering 17/317: timestep 160000
# Rendering 18/317: timestep 170000
# Rendering 19/317: timestep 180000
# Rendering 20/317: timestep 190000
# Rendering 21/317: timestep 200000
# Rendering 22/317: timestep 210000
# Rendering 23/317: timestep 220000
# Rendering 24/317: timestep 230000
# Rendering 25/317: timestep 240000
# Rendering 26/317: timestep 250000
# Rendering 27/317: timestep 260000
# Rendering 28/317: timestep 270000
# Rendering 29/317: timestep 280000
# Rendering 30/317: timestep 290000
# Rendering 31/317: timestep 300000
# Rendering 32/317: timestep 310000
# Rendering 33/317: timestep 320000
# Rendering 34/317: timestep 330000
# Rendering 35/317: timestep 340000
# Rendering 36/317: timestep 350000
# Rendering 37/317: timestep 360000
# Rendering 38/317: timestep 370000
# Rendering 39/317: timestep 380000
# Rendering 40/317: timestep 390000
# Rendering 41/317: timestep 400000
# Rendering 42/317: timestep 410000
# Rendering 43/317: timestep 420000
# Rendering 44/317: timestep 430000
# Rendering 45/317: timestep 440000
# Rendering 46/317: timestep 450000
# Rendering 47/317: timestep 460000
# Rendering 48/317: timestep 470000
# Rendering 49/317: timestep 480000
# Rendering 50/317: timestep 490000
# Rendering 51/317: timestep 500000
# Rendering 52/317: timestep 510000
# Rendering 53/317: timestep 520000
# Rendering 54/317: timestep 530000
# Rendering 55/317: timestep 540000
# Rendering 56/317: timestep 550000
# Rendering 57/317: timestep 560000
# Rendering 58/317: timestep 570000
# Rendering 59/317: timestep 580000
# Rendering 60/317: timestep 590000
# Rendering 61/317: timestep 600000
# Rendering 62/317: timestep 610000
# Rendering 63/317: timestep 620000
# Rendering 64/317: timestep 630000
# Rendering 65/317: timestep 640000
# Rendering 66/317: timestep 650000
# Rendering 67/317: timestep 660000
# Rendering 68/317: timestep 670000
# Rendering 69/317: timestep 680000
# Rendering 70/317: timestep 690000
# Rendering 71/317: timestep 700000
# Rendering 72/317: timestep 710000
# Rendering 73/317: timestep 720000
# Rendering 74/317: timestep 730000
# Rendering 75/317: timestep 740000
# Rendering 76/317: timestep 750000
# Rendering 77/317: timestep 760000
# Rendering 78/317: timestep 770000
# Rendering 246/317: timestep 2450000
# Rendering 247/317: timestep 2460000
# Rendering 248/317: timestep 2470000
# Rendering 249/317: timestep 2480000
# Rendering 250/317: timestep 2490000
# Rendering 251/317: timestep 2500000
# Rendering 252/317: timestep 2510000
# Rendering 253/317: timestep 2520000
# Rendering 254/317: timestep 2530000
# Rendering 255/317: timestep 2540000
# Rendering 256/317: timestep 2550000
# Rendering 257/317: timestep 2560000
# Rendering 258/317: timestep 2570000
# Rendering 259/317: timestep 2580000
# Rendering 260/317: timestep 2590000
# Rendering 261/317: timestep 2600000
# Rendering 262/317: timestep 2610000
# Rendering 263/317: timestep 2620000
# Rendering 264/317: timestep 2630000
# Rendering 265/317: timestep 2640000
# Rendering 266/317: timestep 2650000
# Rendering 267/317: timestep 2660000
# Rendering 268/317: timestep 2670000
# Rendering 269/317: timestep 2680000
# Rendering 270/317: timestep 2690000
# Rendering 271/317: timestep 2700000
# Rendering 272/317: timestep 2710000
# Rendering 273/317: timestep 2720000
# Rendering 274/317: timestep 2730000
# Rendering 275/317: timestep 2740000
# Rendering 276/317: timestep 2750000
# Rendering 277/317: timestep 2760000
# Rendering 278/317: timestep 2770000
# Rendering 279/317: timestep 2780000
# Rendering 280/317: timestep 2790000
# Rendering 281/317: timestep 2800000
# Rendering 282/317: timestep 2810000
# Rendering 283/317: timestep 2820000
# Rendering 284/317: timestep 2830000
# Rendering 285/317: timestep 2840000
# Rendering 286/317: timestep 2850000
# Rendering 287/317: timestep 2860000
# Rendering 288/317: timestep 2870000
# Rendering 289/317: timestep 2880000
# Rendering 290/317: timestep 2890000
# Rendering 291/317: timestep 2900000
# Rendering 292/317: timestep 2910000
# Rendering 293/317: timestep 2920000
# Rendering 294/317: timestep 2930000
# Rendering 295/317: timestep 2940000
# Rendering 296/317: timestep 2950000
# Rendering 297/317: timestep 2960000
# Rendering 298/317: timestep 2970000
# Rendering 299/317: timestep 2980000
# Rendering 300/317: timestep 2990000
# Rendering 301/317: timestep 3000000
# Rendering 302/317: timestep 3010000
# Rendering 303/317: timestep 3020000
# Rendering 304/317: timestep 3030000
# Rendering 305/317: timestep 3040000
# Rendering 306/317: timestep 3050000
# Rendering 307/317: timestep 3060000
# Rendering 308/317: timestep 3070000
# Rendering 309/317: timestep 3080000
# Rendering 310/317: timestep 3090000
# Rendering 311/317: timestep 3100000
# Rendering 312/317: timestep 3110000
# Rendering 313/317: timestep 3120000
# Rendering 314/317: timestep 3130000
# Rendering 315/317: timestep 3140000
# Rendering 316/317: timestep 3150000
# Rendering 317/317: timestep 3160000
# ✅ 2D contour animation saved to: ../outputs/Results/20260707_115008__nsteps=1__mesh=colored_labels_labels/CnP_contour_animation.gif

# %% [markdown]
# To watch video on Mac (local computer):
#
#     1. Download gif file
#     2. Run         ffmpeg -i CnP_contour_animation.gif \
#                    -vf "scale=ceil(iw/2)*2:ceil(ih/2)*2" \
#                    -movflags faststart -pix_fmt yuv420p \
#                     CnP_contour_animation.mp4
