# %% [markdown]
# -------------------------
# ## Compile Plots at All Timesteps for a Video

# %% [markdown]
# ### The below code is for a 3D Plot
#
# - Line #10: Change the directory of the results that will be plotted
# - Line #12: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #13: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize


# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260615_111721__nsteps=200001__mesh=colored_labels_labels"
mesh_file = os.path.join(result_dir, "pmesh_00000")
pattern = os.path.join(result_dir, "phE_[0-9]*")  # skip gif output
output_gif = os.path.join(result_dir, "phE_animation.gif")

# --- Load mesh once ---
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]

print(f"Found {len(files)} snapshots:")
# for f in files:
#     print("  ", os.path.basename(f))

# --- Setup figure once ---
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
# ax.set_title("Electrolyte Potential (phE)")
ax.view_init(elev=30, azim=45)

# norm = Normalize(vmin=0.0, vmax=1.0)
# levels = np.linspace(0, 1, 100) 

# Initialize dummy colorbar
dummy = ax.plot_trisurf(X, Y, np.zeros_like(X), cmap='viridis', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.6, pad=0.1)
dummy.remove()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load grid function
        x = mfem.GridFunction(mesh, fname)
        Z = x.GetDataArray()

        # Auto-compute color scale for this frame
        zmin, zmax = np.min(Z), np.max(Z)

        # Z = np.clip(Z, 0.0, 1.0)

        # zmin, zmax = np.min(Z), np.max(Z)

        # Redraw surface and colorbar
        ax.clear()
        # surf = ax.plot_trisurf(X, Y, Z, cmap='turbo', norm=norm)
        surf = ax.plot_trisurf(X, Y, Z, cmap='turbo')

        ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
        ax.set_title(f"Cathode Concentration (CnC) — timestep {timestep}")
        # ax.set_zlim(0.0, 1.0)
        # Update colorbar each frame
        cbar.ax.clear()
        fig.colorbar(surf, cax=cbar.ax)
        # cbar.ax.set_ylabel("Potential")

        # Save frame
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

os.remove("temp_frame.png")
print(f"✅ Animation saved to: {output_gif}")

# %% [markdown]
# ### The below code is for a 2D Contour Plot
#
# - Line #9: Change the directory of the results that will be plotted
# - Line #11: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #12: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize

# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260702_111746__nsteps=1__mesh=colored_labels_labels"
mesh_file = os.path.join(result_dir, "pmesh")
# mesh_file = os.path.join("../MSU_HPCC/pmesh")
pattern = os.path.join(result_dir, "CnP_total_[0-9]*")
output_gif = os.path.join(result_dir, "CnP_contour_animation.gif")

# --- Load mesh once --/
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Get vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]
# files = [f for f in files if get_timestep(f) % 1000 == 0]

print(f"Found {len(files)} snapshots:")

# --- Setup figure ---
fig, ax = plt.subplots(figsize=(7, 6))
ax.set_aspect('equal', adjustable='box')
ax.set_xticks([]); ax.set_yticks([])
plt.tight_layout()

# ✅ Fixed normalization and levels
norm = Normalize(vmin=0.0, vmax=0.25)
levels = np.linspace(0, 0.25, 100) 

# Dummy contour for fixed 0–1 colorbar
dummy = ax.tricontourf(X, Y, np.zeros_like(X), levels=levels, cmap='turbo', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.8, pad=0.02)
cbar.set_label("Lithium Concentration")
ax.clear()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load MFEM GridFunction data
        gf = mfem.GridFunction(mesh, fname)
        Z = gf.GetDataArray()

        Z = np.clip(Z, 0.0, 0.25) # Forcing values within [0, 1.0]

        ax.clear()
        cntr = ax.tricontourf(X, Y, Z, levels=levels, cmap='turbo', norm=norm)
        ax.set_aspect('equal', adjustable='box')
        ax.set_xticks([]); ax.set_yticks([])
        ax.set_title(f"Lithium Concentration — timestep {timestep}")

        # Save frame to temp file
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

# Clean up temporary frame
os.remove("temp_frame.png")
print(f"✅ 2D contour animation saved to: {output_gif}")
# Out:
# Found 828 snapshots:
# Rendering 1/828: timestep 0
# /tmp/ipykernel_382054/2581968144.py:78: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   writer.append_data(imageio.imread(frame_path))
# Rendering 2/828: timestep 10000
# Rendering 3/828: timestep 20000
# Rendering 4/828: timestep 30000
# Rendering 5/828: timestep 40000
# Rendering 6/828: timestep 50000
# Rendering 7/828: timestep 60000
# Rendering 8/828: timestep 70000
# Rendering 9/828: timestep 80000
# Rendering 10/828: timestep 90000
# Rendering 11/828: timestep 100000
# Rendering 12/828: timestep 110000
# Rendering 13/828: timestep 120000
# Rendering 14/828: timestep 130000
# Rendering 15/828: timestep 140000
# Rendering 16/828: timestep 150000
# Rendering 17/828: timestep 160000
# Rendering 18/828: timestep 170000
# Rendering 19/828: timestep 180000
# Rendering 20/828: timestep 190000
# Rendering 21/828: timestep 200000
# Rendering 22/828: timestep 210000
# Rendering 23/828: timestep 220000
# Rendering 24/828: timestep 230000
# Rendering 25/828: timestep 240000
# Rendering 26/828: timestep 250000
# Rendering 27/828: timestep 260000
# Rendering 28/828: timestep 270000
# Rendering 29/828: timestep 280000
# Rendering 30/828: timestep 290000
# Rendering 31/828: timestep 300000
# Rendering 32/828: timestep 310000
# Rendering 33/828: timestep 320000
# Rendering 34/828: timestep 330000
# Rendering 35/828: timestep 340000
# Rendering 36/828: timestep 350000
# Rendering 37/828: timestep 360000
# Rendering 38/828: timestep 370000
# Rendering 39/828: timestep 380000
# Rendering 40/828: timestep 390000
# Rendering 41/828: timestep 400000
# Rendering 42/828: timestep 410000
# Rendering 43/828: timestep 420000
# Rendering 44/828: timestep 430000
# Rendering 45/828: timestep 440000
# Rendering 46/828: timestep 450000
# Rendering 47/828: timestep 460000
# Rendering 48/828: timestep 470000
# Rendering 49/828: timestep 480000
# Rendering 50/828: timestep 490000
# Rendering 51/828: timestep 500000
# Rendering 52/828: timestep 510000
# Rendering 53/828: timestep 520000
# Rendering 54/828: timestep 530000
# Rendering 55/828: timestep 540000
# Rendering 56/828: timestep 550000
# Rendering 57/828: timestep 560000
# Rendering 58/828: timestep 570000
# Rendering 59/828: timestep 580000
# Rendering 60/828: timestep 590000
# Rendering 61/828: timestep 600000
# Rendering 62/828: timestep 610000
# Rendering 63/828: timestep 620000
# Rendering 64/828: timestep 630000
# Rendering 65/828: timestep 640000
# Rendering 66/828: timestep 650000
# Rendering 67/828: timestep 660000
# Rendering 68/828: timestep 670000
# Rendering 69/828: timestep 680000
# Rendering 70/828: timestep 690000
# Rendering 71/828: timestep 700000
# Rendering 72/828: timestep 710000
# Rendering 73/828: timestep 720000
# Rendering 74/828: timestep 730000
# Rendering 75/828: timestep 740000
# Rendering 76/828: timestep 750000
# Rendering 77/828: timestep 760000
# Rendering 78/828: timestep 770000
# Rendering 79/828: timestep 780000
# Rendering 80/828: timestep 790000
# Rendering 81/828: timestep 800000
# Rendering 82/828: timestep 810000
# Rendering 83/828: timestep 820000
# Rendering 84/828: timestep 830000
# Rendering 85/828: timestep 840000
# Rendering 86/828: timestep 850000
# Rendering 87/828: timestep 860000
# Rendering 88/828: timestep 870000
# Rendering 89/828: timestep 880000
# Rendering 90/828: timestep 890000
# Rendering 91/828: timestep 900000
# Rendering 92/828: timestep 910000
# Rendering 93/828: timestep 920000
# Rendering 94/828: timestep 930000
# Rendering 95/828: timestep 940000
# Rendering 96/828: timestep 950000
# Rendering 97/828: timestep 960000
# Rendering 98/828: timestep 970000
# Rendering 99/828: timestep 980000
# Rendering 100/828: timestep 990000
# Rendering 101/828: timestep 1000000
# Rendering 102/828: timestep 1010000
# Rendering 103/828: timestep 1020000
# Rendering 104/828: timestep 1030000
# Rendering 105/828: timestep 1040000
# Rendering 106/828: timestep 1050000
# Rendering 107/828: timestep 1060000
# Rendering 108/828: timestep 1070000
# Rendering 109/828: timestep 1080000
# Rendering 110/828: timestep 1090000
# Rendering 111/828: timestep 1100000
# Rendering 112/828: timestep 1110000
# Rendering 113/828: timestep 1120000
# Rendering 114/828: timestep 1130000
# Rendering 115/828: timestep 1140000
# Rendering 116/828: timestep 1150000
# Rendering 117/828: timestep 1160000
# Rendering 118/828: timestep 1170000
# Rendering 119/828: timestep 1180000
# Rendering 120/828: timestep 1190000
# Rendering 121/828: timestep 1200000
# Rendering 122/828: timestep 1210000
# Rendering 123/828: timestep 1220000
# Rendering 124/828: timestep 1230000
# Rendering 125/828: timestep 1240000
# Rendering 126/828: timestep 1250000
# Rendering 127/828: timestep 1260000
# Rendering 128/828: timestep 1270000
# Rendering 129/828: timestep 1280000
# Rendering 130/828: timestep 1290000
# Rendering 131/828: timestep 1300000
# Rendering 132/828: timestep 1310000
# Rendering 133/828: timestep 1320000
# Rendering 134/828: timestep 1330000
# Rendering 135/828: timestep 1340000
# Rendering 136/828: timestep 1350000
# Rendering 137/828: timestep 1360000
# Rendering 138/828: timestep 1370000
# Rendering 139/828: timestep 1380000
# Rendering 140/828: timestep 1390000
# Rendering 141/828: timestep 1400000
# Rendering 142/828: timestep 1410000
# Rendering 143/828: timestep 1420000
# Rendering 144/828: timestep 1430000
# Rendering 145/828: timestep 1440000
# Rendering 146/828: timestep 1450000
# Rendering 147/828: timestep 1460000
# Rendering 148/828: timestep 1470000
# Rendering 149/828: timestep 1480000
# Rendering 150/828: timestep 1490000
# Rendering 151/828: timestep 1500000
# Rendering 152/828: timestep 1510000
# Rendering 153/828: timestep 1520000
# Rendering 154/828: timestep 1530000
# Rendering 155/828: timestep 1540000
# Rendering 156/828: timestep 1550000
# Rendering 157/828: timestep 1560000
# Rendering 158/828: timestep 1570000
# Rendering 159/828: timestep 1580000
# Rendering 160/828: timestep 1590000
# Rendering 161/828: timestep 1600000
# Rendering 162/828: timestep 1610000
# Rendering 163/828: timestep 1620000
# Rendering 164/828: timestep 1630000
# Rendering 165/828: timestep 1640000
# Rendering 166/828: timestep 1650000
# Rendering 167/828: timestep 1660000
# Rendering 168/828: timestep 1670000
# Rendering 169/828: timestep 1680000
# Rendering 170/828: timestep 1690000
# Rendering 171/828: timestep 1700000
# Rendering 172/828: timestep 1710000
# Rendering 173/828: timestep 1720000
# Rendering 174/828: timestep 1730000
# Rendering 175/828: timestep 1740000
# Rendering 176/828: timestep 1750000
# Rendering 177/828: timestep 1760000
# Rendering 178/828: timestep 1770000
# Rendering 179/828: timestep 1780000
# Rendering 180/828: timestep 1790000
# Rendering 181/828: timestep 1800000
# Rendering 182/828: timestep 1810000
# Rendering 183/828: timestep 1820000
# Rendering 184/828: timestep 1830000
# Rendering 185/828: timestep 1840000
# Rendering 186/828: timestep 1850000
# Rendering 187/828: timestep 1860000
# Rendering 188/828: timestep 1870000
# Rendering 189/828: timestep 1880000
# Rendering 190/828: timestep 1890000
# Rendering 191/828: timestep 1900000
# Rendering 192/828: timestep 1910000
# Rendering 193/828: timestep 1920000
# Rendering 194/828: timestep 1930000
# Rendering 195/828: timestep 1940000
# Rendering 196/828: timestep 1950000
# Rendering 197/828: timestep 1960000
# Rendering 198/828: timestep 1970000
# Rendering 199/828: timestep 1980000
# Rendering 200/828: timestep 1990000
# Rendering 201/828: timestep 2000000
# Rendering 202/828: timestep 2010000
# Rendering 203/828: timestep 2020000
# Rendering 204/828: timestep 2030000
# Rendering 205/828: timestep 2040000
# Rendering 206/828: timestep 2050000
# Rendering 207/828: timestep 2060000
# Rendering 208/828: timestep 2070000
# Rendering 209/828: timestep 2080000
# Rendering 210/828: timestep 2090000
# Rendering 211/828: timestep 2100000
# Rendering 212/828: timestep 2110000
# Rendering 213/828: timestep 2120000
# Rendering 214/828: timestep 2130000
# Rendering 215/828: timestep 2140000
# Rendering 216/828: timestep 2150000
# Rendering 217/828: timestep 2160000
# Rendering 218/828: timestep 2170000
# Rendering 219/828: timestep 2180000
# Rendering 220/828: timestep 2190000
# Rendering 221/828: timestep 2200000
# Rendering 222/828: timestep 2210000
# Rendering 223/828: timestep 2220000
# Rendering 224/828: timestep 2230000
# Rendering 225/828: timestep 2240000
# Rendering 226/828: timestep 2250000
# Rendering 227/828: timestep 2260000
# Rendering 228/828: timestep 2270000
# Rendering 229/828: timestep 2280000
# Rendering 230/828: timestep 2290000
# Rendering 231/828: timestep 2300000
# Rendering 232/828: timestep 2310000
# Rendering 233/828: timestep 2320000
# Rendering 234/828: timestep 2330000
# Rendering 235/828: timestep 2340000
# Rendering 236/828: timestep 2350000
# Rendering 237/828: timestep 2360000
# Rendering 238/828: timestep 2370000
# Rendering 239/828: timestep 2380000
# Rendering 240/828: timestep 2390000
# Rendering 241/828: timestep 2400000
# Rendering 242/828: timestep 2410000
# Rendering 243/828: timestep 2420000
# Rendering 244/828: timestep 2430000
# Rendering 245/828: timestep 2440000
# Rendering 246/828: timestep 2450000
# Rendering 247/828: timestep 2460000
# Rendering 248/828: timestep 2470000
# Rendering 249/828: timestep 2480000
# Rendering 250/828: timestep 2490000
# Rendering 251/828: timestep 2500000
# Rendering 252/828: timestep 2510000
# Rendering 253/828: timestep 2520000
# Rendering 254/828: timestep 2530000
# Rendering 255/828: timestep 2540000
# Rendering 256/828: timestep 2550000
# Rendering 257/828: timestep 2560000
# Rendering 258/828: timestep 2570000
# Rendering 259/828: timestep 2580000
# Rendering 260/828: timestep 2590000
# Rendering 261/828: timestep 2600000
# Rendering 262/828: timestep 2610000
# Rendering 263/828: timestep 2620000
# Rendering 264/828: timestep 2630000
# Rendering 265/828: timestep 2640000
# Rendering 266/828: timestep 2650000
# Rendering 267/828: timestep 2660000
# Rendering 268/828: timestep 2670000
# Rendering 269/828: timestep 2680000
# Rendering 270/828: timestep 2690000
# Rendering 271/828: timestep 2700000
# Rendering 272/828: timestep 2710000
# Rendering 273/828: timestep 2720000
# Rendering 274/828: timestep 2730000
# Rendering 275/828: timestep 2740000
# Rendering 276/828: timestep 2750000
# Rendering 277/828: timestep 2760000
# Rendering 278/828: timestep 2770000
# Rendering 279/828: timestep 2780000
# Rendering 280/828: timestep 2790000
# Rendering 281/828: timestep 2800000
# Rendering 282/828: timestep 2810000
# Rendering 283/828: timestep 2820000
# Rendering 284/828: timestep 2830000
# Rendering 285/828: timestep 2840000
# Rendering 286/828: timestep 2850000
# Rendering 287/828: timestep 2860000
# Rendering 288/828: timestep 2870000
# Rendering 289/828: timestep 2880000
# Rendering 290/828: timestep 2890000
# Rendering 291/828: timestep 2900000
# Rendering 292/828: timestep 2910000
# Rendering 293/828: timestep 2920000
# Rendering 294/828: timestep 2930000
# Rendering 295/828: timestep 2940000
# Rendering 296/828: timestep 2950000
# Rendering 297/828: timestep 2960000
# Rendering 298/828: timestep 2970000
# Rendering 299/828: timestep 2980000
# Rendering 300/828: timestep 2990000
# Rendering 301/828: timestep 3000000
# Rendering 302/828: timestep 3010000
# Rendering 303/828: timestep 3020000
# Rendering 304/828: timestep 3030000
# Rendering 305/828: timestep 3040000
# Rendering 306/828: timestep 3050000
# Rendering 307/828: timestep 3060000
# Rendering 308/828: timestep 3070000
# Rendering 309/828: timestep 3080000
# Rendering 310/828: timestep 3090000
# Rendering 311/828: timestep 3100000
# Rendering 312/828: timestep 3110000
# Rendering 313/828: timestep 3120000
# Rendering 314/828: timestep 3130000
# Rendering 315/828: timestep 3140000
# Rendering 316/828: timestep 3150000
# Rendering 317/828: timestep 3160000
# Rendering 318/828: timestep 3170000
# Rendering 319/828: timestep 3180000
# Rendering 320/828: timestep 3190000
# Rendering 321/828: timestep 3200000
# Rendering 322/828: timestep 3210000
# Rendering 323/828: timestep 3220000
# Rendering 324/828: timestep 3230000
# Rendering 325/828: timestep 3240000
# Rendering 326/828: timestep 3250000
# Rendering 327/828: timestep 3260000
# Rendering 328/828: timestep 3270000
# Rendering 329/828: timestep 3280000
# Rendering 330/828: timestep 3290000
# Rendering 331/828: timestep 3300000
# Rendering 332/828: timestep 3310000
# Rendering 333/828: timestep 3320000
# Rendering 334/828: timestep 3330000
# Rendering 335/828: timestep 3340000
# Rendering 336/828: timestep 3350000
# Rendering 337/828: timestep 3360000
# Rendering 338/828: timestep 3370000
# Rendering 339/828: timestep 3380000
# Rendering 340/828: timestep 3390000
# Rendering 341/828: timestep 3400000
# Rendering 342/828: timestep 3410000
# Rendering 343/828: timestep 3420000
# Rendering 344/828: timestep 3430000
# Rendering 345/828: timestep 3440000
# Rendering 346/828: timestep 3450000
# Rendering 347/828: timestep 3460000
# Rendering 348/828: timestep 3470000
# Rendering 349/828: timestep 3480000
# Rendering 350/828: timestep 3490000
# Rendering 351/828: timestep 3500000
# Rendering 352/828: timestep 3510000
# Rendering 353/828: timestep 3520000
# Rendering 354/828: timestep 3530000
# Rendering 355/828: timestep 3540000
# Rendering 356/828: timestep 3550000
# Rendering 357/828: timestep 3560000
# Rendering 358/828: timestep 3570000
# Rendering 359/828: timestep 3580000
# Rendering 360/828: timestep 3590000
# Rendering 361/828: timestep 3600000
# Rendering 362/828: timestep 3610000
# Rendering 363/828: timestep 3620000
# Rendering 364/828: timestep 3630000
# Rendering 365/828: timestep 3640000
# Rendering 366/828: timestep 3650000
# Rendering 367/828: timestep 3660000
# Rendering 368/828: timestep 3670000
# Rendering 369/828: timestep 3680000
# Rendering 370/828: timestep 3690000
# Rendering 371/828: timestep 3700000
# Rendering 372/828: timestep 3710000
# Rendering 373/828: timestep 3720000
# Rendering 374/828: timestep 3730000
# Rendering 375/828: timestep 3740000
# Rendering 376/828: timestep 3750000
# Rendering 377/828: timestep 3760000
# Rendering 378/828: timestep 3770000
# Rendering 379/828: timestep 3780000
# Rendering 380/828: timestep 3790000
# Rendering 381/828: timestep 3800000
# Rendering 382/828: timestep 3810000
# Rendering 383/828: timestep 3820000
# Rendering 384/828: timestep 3830000
# Rendering 385/828: timestep 3840000
# Rendering 386/828: timestep 3850000
# Rendering 387/828: timestep 3860000
# Rendering 388/828: timestep 3870000
# Rendering 389/828: timestep 3880000
# Rendering 390/828: timestep 3890000
# Rendering 391/828: timestep 3900000
# Rendering 392/828: timestep 3910000
# Rendering 393/828: timestep 3920000
# Rendering 394/828: timestep 3930000
# Rendering 395/828: timestep 3940000
# Rendering 396/828: timestep 3950000
# Rendering 397/828: timestep 3960000
# Rendering 398/828: timestep 3970000
# Rendering 399/828: timestep 3980000
# Rendering 400/828: timestep 3990000
# Rendering 401/828: timestep 4000000
# Rendering 402/828: timestep 4010000
# Rendering 403/828: timestep 4020000
# Rendering 404/828: timestep 4030000
# Rendering 405/828: timestep 4040000
# Rendering 406/828: timestep 4050000
# Rendering 407/828: timestep 4060000
# Rendering 408/828: timestep 4070000
# Rendering 409/828: timestep 4080000
# Rendering 410/828: timestep 4090000
# Rendering 411/828: timestep 4100000
# Rendering 412/828: timestep 4110000
# Rendering 413/828: timestep 4120000
# Rendering 414/828: timestep 4130000
# Rendering 415/828: timestep 4140000
# Rendering 416/828: timestep 4150000
# Rendering 417/828: timestep 4160000
# Rendering 418/828: timestep 4170000
# Rendering 419/828: timestep 4180000
# Rendering 420/828: timestep 4190000
# Rendering 421/828: timestep 4200000
# Rendering 422/828: timestep 4210000
# Rendering 423/828: timestep 4220000
# Rendering 424/828: timestep 4230000
# Rendering 425/828: timestep 4240000
# Rendering 426/828: timestep 4250000
# Rendering 427/828: timestep 4260000
# Rendering 428/828: timestep 4270000
# Rendering 429/828: timestep 4280000
# Rendering 430/828: timestep 4290000
# Rendering 431/828: timestep 4300000
# Rendering 432/828: timestep 4310000
# Rendering 433/828: timestep 4320000
# Rendering 434/828: timestep 4330000
# Rendering 435/828: timestep 4340000
# Rendering 436/828: timestep 4350000
# Rendering 437/828: timestep 4360000
# Rendering 438/828: timestep 4370000
# Rendering 439/828: timestep 4380000
# Rendering 440/828: timestep 4390000
# Rendering 441/828: timestep 4400000
# Rendering 442/828: timestep 4410000
# Rendering 443/828: timestep 4420000
# Rendering 444/828: timestep 4430000
# Rendering 445/828: timestep 4440000
# Rendering 446/828: timestep 4450000
# Rendering 447/828: timestep 4460000
# Rendering 448/828: timestep 4470000
# Rendering 449/828: timestep 4480000
# Rendering 450/828: timestep 4490000
# Rendering 451/828: timestep 4500000
# Rendering 452/828: timestep 4510000
# Rendering 453/828: timestep 4520000
# Rendering 454/828: timestep 4530000
# Rendering 455/828: timestep 4540000
# Rendering 456/828: timestep 4550000
# Rendering 457/828: timestep 4560000
# Rendering 458/828: timestep 4570000
# Rendering 459/828: timestep 4580000
# Rendering 460/828: timestep 4590000
# Rendering 461/828: timestep 4600000
# Rendering 462/828: timestep 4610000
# Rendering 463/828: timestep 4620000
# Rendering 464/828: timestep 4630000
# Rendering 465/828: timestep 4640000
# Rendering 466/828: timestep 4650000
# Rendering 467/828: timestep 4660000
# Rendering 468/828: timestep 4670000
# Rendering 469/828: timestep 4680000
# Rendering 470/828: timestep 4690000
# Rendering 471/828: timestep 4700000
# Rendering 472/828: timestep 4710000
# Rendering 473/828: timestep 4720000
# Rendering 474/828: timestep 4730000
# Rendering 475/828: timestep 4740000
# Rendering 476/828: timestep 4750000
# Rendering 477/828: timestep 4760000
# Rendering 478/828: timestep 4770000
# Rendering 479/828: timestep 4780000
# Rendering 480/828: timestep 4790000
# Rendering 481/828: timestep 4800000
# Rendering 482/828: timestep 4810000
# Rendering 483/828: timestep 4820000
# Rendering 484/828: timestep 4830000
# Rendering 485/828: timestep 4840000
# Rendering 486/828: timestep 4850000
# Rendering 487/828: timestep 4860000
# Rendering 488/828: timestep 4870000
# Rendering 489/828: timestep 4880000
# Rendering 490/828: timestep 4890000
# Rendering 491/828: timestep 4900000
# Rendering 492/828: timestep 4910000
# Rendering 493/828: timestep 4920000
# Rendering 494/828: timestep 4930000
# Rendering 495/828: timestep 4940000
# Rendering 496/828: timestep 4950000
# Rendering 497/828: timestep 4960000
# Rendering 498/828: timestep 4970000
# Rendering 499/828: timestep 4980000
# Rendering 500/828: timestep 4990000
# Rendering 501/828: timestep 5000000
# Rendering 502/828: timestep 5010000
# Rendering 503/828: timestep 5020000
# Rendering 504/828: timestep 5030000
# Rendering 505/828: timestep 5040000
# Rendering 506/828: timestep 5050000
# Rendering 507/828: timestep 5060000
# Rendering 508/828: timestep 5070000
# Rendering 509/828: timestep 5080000
# Rendering 510/828: timestep 5090000
# Rendering 511/828: timestep 5100000
# Rendering 512/828: timestep 5110000
# Rendering 513/828: timestep 5120000
# Rendering 514/828: timestep 5130000
# Rendering 515/828: timestep 5140000
# Rendering 516/828: timestep 5150000
# Rendering 517/828: timestep 5160000
# Rendering 518/828: timestep 5170000
# Rendering 519/828: timestep 5180000
# Rendering 520/828: timestep 5190000
# Rendering 521/828: timestep 5200000
# Rendering 522/828: timestep 5210000
# Rendering 523/828: timestep 5220000
# Rendering 524/828: timestep 5230000
# Rendering 525/828: timestep 5240000
# Rendering 526/828: timestep 5250000
# Rendering 527/828: timestep 5260000
# Rendering 528/828: timestep 5270000
# Rendering 529/828: timestep 5280000
# Rendering 530/828: timestep 5290000
# Rendering 531/828: timestep 5300000
# Rendering 532/828: timestep 5310000
# Rendering 533/828: timestep 5320000
# Rendering 534/828: timestep 5330000
# Rendering 535/828: timestep 5340000
# Rendering 536/828: timestep 5350000
# Rendering 537/828: timestep 5360000
# Rendering 538/828: timestep 5370000
# Rendering 539/828: timestep 5380000
# Rendering 540/828: timestep 5390000
# Rendering 541/828: timestep 5400000
# Rendering 542/828: timestep 5410000
# Rendering 543/828: timestep 5420000
# Rendering 544/828: timestep 5430000
# Rendering 545/828: timestep 5440000
# Rendering 546/828: timestep 5450000
# Rendering 547/828: timestep 5460000
# Rendering 548/828: timestep 5470000
# Rendering 549/828: timestep 5480000
# Rendering 550/828: timestep 5490000
# Rendering 551/828: timestep 5500000
# Rendering 552/828: timestep 5510000
# Rendering 553/828: timestep 5520000
# Rendering 554/828: timestep 5530000
# Rendering 555/828: timestep 5540000
# Rendering 556/828: timestep 5550000
# Rendering 557/828: timestep 5560000
# Rendering 558/828: timestep 5570000
# Rendering 559/828: timestep 5580000
# Rendering 560/828: timestep 5590000
# Rendering 561/828: timestep 5600000
# Rendering 562/828: timestep 5610000
# Rendering 563/828: timestep 5620000
# Rendering 564/828: timestep 5630000
# Rendering 565/828: timestep 5640000
# Rendering 566/828: timestep 5650000
# Rendering 567/828: timestep 5660000
# Rendering 568/828: timestep 5670000
# Rendering 569/828: timestep 5680000
# Rendering 570/828: timestep 5690000
# Rendering 571/828: timestep 5700000
# Rendering 572/828: timestep 5710000
# Rendering 573/828: timestep 5720000
# Rendering 574/828: timestep 5730000
# Rendering 575/828: timestep 5740000
# Rendering 576/828: timestep 5750000
# Rendering 577/828: timestep 5760000
# Rendering 578/828: timestep 5770000
# Rendering 579/828: timestep 5780000
# Rendering 580/828: timestep 5790000
# Rendering 581/828: timestep 5800000
# Rendering 582/828: timestep 5810000
# Rendering 583/828: timestep 5820000
# Rendering 584/828: timestep 5830000
# Rendering 585/828: timestep 5840000
# Rendering 586/828: timestep 5850000
# Rendering 587/828: timestep 5860000
# Rendering 588/828: timestep 5870000
# Rendering 589/828: timestep 5880000
# Rendering 590/828: timestep 5890000
# Rendering 591/828: timestep 5900000
# Rendering 592/828: timestep 5910000
# Rendering 593/828: timestep 5920000
# Rendering 594/828: timestep 5930000
# Rendering 595/828: timestep 5940000
# Rendering 596/828: timestep 5950000
# Rendering 597/828: timestep 5960000
# Rendering 598/828: timestep 5970000
# Rendering 599/828: timestep 5980000
# Rendering 600/828: timestep 5990000
# Rendering 601/828: timestep 6000000
# Rendering 602/828: timestep 6010000
# Rendering 603/828: timestep 6020000
# Rendering 604/828: timestep 6030000
# Rendering 605/828: timestep 6040000
# Rendering 606/828: timestep 6050000
# Rendering 607/828: timestep 6060000
# Rendering 608/828: timestep 6070000
# Rendering 609/828: timestep 6080000
# Rendering 610/828: timestep 6090000
# Rendering 611/828: timestep 6100000
# Rendering 612/828: timestep 6110000
# Rendering 613/828: timestep 6120000
# Rendering 614/828: timestep 6130000
# Rendering 615/828: timestep 6140000
# Rendering 616/828: timestep 6150000
# Rendering 617/828: timestep 6160000
# Rendering 618/828: timestep 6170000
# Rendering 619/828: timestep 6180000
# Rendering 620/828: timestep 6190000
# Rendering 621/828: timestep 6200000
# Rendering 622/828: timestep 6210000
# Rendering 623/828: timestep 6220000
# Rendering 624/828: timestep 6230000
# Rendering 625/828: timestep 6240000
# Rendering 626/828: timestep 6250000
# Rendering 627/828: timestep 6260000
# Rendering 628/828: timestep 6270000
# Rendering 629/828: timestep 6280000
# Rendering 630/828: timestep 6290000
# Rendering 631/828: timestep 6300000
# Rendering 632/828: timestep 6310000
# Rendering 633/828: timestep 6320000
# Rendering 634/828: timestep 6330000
# Rendering 635/828: timestep 6340000
# Rendering 636/828: timestep 6350000
# Rendering 637/828: timestep 6360000
# Rendering 638/828: timestep 6370000
# Rendering 639/828: timestep 6380000
# Rendering 640/828: timestep 6390000
# Rendering 641/828: timestep 6400000
# Rendering 642/828: timestep 6410000
# Rendering 643/828: timestep 6420000
# Rendering 644/828: timestep 6430000
# Rendering 645/828: timestep 6440000
# Rendering 646/828: timestep 6450000
# Rendering 647/828: timestep 6460000
# Rendering 648/828: timestep 6470000
# Rendering 649/828: timestep 6480000
# Rendering 650/828: timestep 6490000
# Rendering 651/828: timestep 6500000
# Rendering 652/828: timestep 6510000
# Rendering 653/828: timestep 6520000
# Rendering 654/828: timestep 6530000
# Rendering 655/828: timestep 6540000
# Rendering 656/828: timestep 6550000
# Rendering 657/828: timestep 6560000
# Rendering 658/828: timestep 6570000
# Rendering 659/828: timestep 6580000
# Rendering 660/828: timestep 6590000
# Rendering 661/828: timestep 6600000
# Rendering 662/828: timestep 6610000
# Rendering 663/828: timestep 6620000
# Rendering 664/828: timestep 6630000
# Rendering 665/828: timestep 6640000
# Rendering 666/828: timestep 6650000
# Rendering 667/828: timestep 6660000
# Rendering 668/828: timestep 6670000
# Rendering 669/828: timestep 6680000
# Rendering 670/828: timestep 6690000
# Rendering 671/828: timestep 6700000
# Rendering 672/828: timestep 6710000
# Rendering 673/828: timestep 6720000
# Rendering 674/828: timestep 6730000
# Rendering 675/828: timestep 6740000
# Rendering 676/828: timestep 6750000
# Rendering 677/828: timestep 6760000
# Rendering 678/828: timestep 6770000
# Rendering 679/828: timestep 6780000
# Rendering 680/828: timestep 6790000
# Rendering 681/828: timestep 6800000
# Rendering 682/828: timestep 6810000
# Rendering 683/828: timestep 6820000
# Rendering 684/828: timestep 6830000
# Rendering 685/828: timestep 6840000
# Rendering 686/828: timestep 6850000
# Rendering 687/828: timestep 6860000
# Rendering 688/828: timestep 6870000
# Rendering 689/828: timestep 6880000
# Rendering 690/828: timestep 6890000
# Rendering 691/828: timestep 6900000
# Rendering 692/828: timestep 6910000
# Rendering 693/828: timestep 6920000
# Rendering 694/828: timestep 6930000
# Rendering 695/828: timestep 6940000
# Rendering 696/828: timestep 6950000
# Rendering 697/828: timestep 6960000
# Rendering 698/828: timestep 6970000
# Rendering 699/828: timestep 6980000
# Rendering 700/828: timestep 6990000
# Rendering 701/828: timestep 7000000
# Rendering 702/828: timestep 7010000
# Rendering 703/828: timestep 7020000
# Rendering 704/828: timestep 7030000
# Rendering 705/828: timestep 7040000
# Rendering 706/828: timestep 7050000
# Rendering 707/828: timestep 7060000
# Rendering 708/828: timestep 7070000
# Rendering 709/828: timestep 7080000
# Rendering 710/828: timestep 7090000
# Rendering 711/828: timestep 7100000
# Rendering 712/828: timestep 7110000
# Rendering 713/828: timestep 7120000
# Rendering 714/828: timestep 7130000
# Rendering 715/828: timestep 7140000
# Rendering 716/828: timestep 7150000
# Rendering 717/828: timestep 7160000
# Rendering 718/828: timestep 7170000
# Rendering 719/828: timestep 7180000
# Rendering 720/828: timestep 7190000
# Rendering 721/828: timestep 7200000
# Rendering 722/828: timestep 7210000
# Rendering 723/828: timestep 7220000
# Rendering 724/828: timestep 7230000
# Rendering 725/828: timestep 7240000
# Rendering 726/828: timestep 7250000
# Rendering 727/828: timestep 7260000
# Rendering 728/828: timestep 7270000
# Rendering 729/828: timestep 7280000
# Rendering 730/828: timestep 7290000
# Rendering 731/828: timestep 7300000
# Rendering 732/828: timestep 7310000
# Rendering 733/828: timestep 7320000
# Rendering 734/828: timestep 7330000
# Rendering 735/828: timestep 7340000
# Rendering 736/828: timestep 7350000
# Rendering 737/828: timestep 7360000
# Rendering 738/828: timestep 7370000
# Rendering 739/828: timestep 7380000
# Rendering 740/828: timestep 7390000
# Rendering 741/828: timestep 7400000
# Rendering 742/828: timestep 7410000
# Rendering 743/828: timestep 7420000
# Rendering 744/828: timestep 7430000
# Rendering 745/828: timestep 7440000
# Rendering 746/828: timestep 7450000
# Rendering 747/828: timestep 7460000
# Rendering 748/828: timestep 7470000
# Rendering 749/828: timestep 7480000
# Rendering 750/828: timestep 7490000
# Rendering 751/828: timestep 7500000
# Rendering 752/828: timestep 7510000
# Rendering 753/828: timestep 7520000
# Rendering 754/828: timestep 7530000
# Rendering 755/828: timestep 7540000
# Rendering 756/828: timestep 7550000
# Rendering 757/828: timestep 7560000
# Rendering 758/828: timestep 7570000
# Rendering 759/828: timestep 7580000
# Rendering 760/828: timestep 7590000
# Rendering 761/828: timestep 7600000
# Rendering 762/828: timestep 7610000
# Rendering 763/828: timestep 7620000
# Rendering 764/828: timestep 7630000
# Rendering 765/828: timestep 7640000
# Rendering 766/828: timestep 7650000
# Rendering 767/828: timestep 7660000
# Rendering 768/828: timestep 7670000
# Rendering 769/828: timestep 7680000
# Rendering 770/828: timestep 7690000
# Rendering 771/828: timestep 7700000
# Rendering 772/828: timestep 7710000
# Rendering 773/828: timestep 7720000
# Rendering 774/828: timestep 7730000
# Rendering 775/828: timestep 7740000
# Rendering 776/828: timestep 7750000
# Rendering 777/828: timestep 7760000
# Rendering 778/828: timestep 7770000
# Rendering 779/828: timestep 7780000
# Rendering 780/828: timestep 7790000
# Rendering 781/828: timestep 7800000
# Rendering 782/828: timestep 7810000
# Rendering 783/828: timestep 7820000
# Rendering 784/828: timestep 7830000
# Rendering 785/828: timestep 7840000
# Rendering 786/828: timestep 7850000
# Rendering 787/828: timestep 7860000
# Rendering 788/828: timestep 7870000
# Rendering 789/828: timestep 7880000
# Rendering 790/828: timestep 7890000
# Rendering 791/828: timestep 7900000
# Rendering 792/828: timestep 7910000
# Rendering 793/828: timestep 7920000
# Rendering 794/828: timestep 7930000
# Rendering 795/828: timestep 7940000
# Rendering 796/828: timestep 7950000
# Rendering 797/828: timestep 7960000
# Rendering 798/828: timestep 7970000
# Rendering 799/828: timestep 7980000
# Rendering 800/828: timestep 7990000
# Rendering 801/828: timestep 8000000
# Rendering 802/828: timestep 8010000
# Rendering 803/828: timestep 8020000
# Rendering 804/828: timestep 8030000
# Rendering 805/828: timestep 8040000
# Rendering 806/828: timestep 8050000
# Rendering 807/828: timestep 8060000
# Rendering 808/828: timestep 8070000
# Rendering 809/828: timestep 8080000
# Rendering 810/828: timestep 8090000
# Rendering 811/828: timestep 8100000
# Rendering 812/828: timestep 8110000
# Rendering 813/828: timestep 8120000
# Rendering 814/828: timestep 8130000
# Rendering 815/828: timestep 8140000
# Rendering 816/828: timestep 8150000
# Rendering 817/828: timestep 8160000
# Rendering 818/828: timestep 8170000
# Rendering 819/828: timestep 8180000
# Rendering 820/828: timestep 8190000
# Rendering 821/828: timestep 8200000
# Rendering 822/828: timestep 8210000
# Rendering 823/828: timestep 8220000
# Rendering 824/828: timestep 8230000
# Rendering 825/828: timestep 8240000
# Rendering 826/828: timestep 8250000
# Rendering 827/828: timestep 8260000
# Rendering 828/828: timestep 8270000
# ✅ 2D contour animation saved to: ../outputs/Results/20260701_153151__nsteps=1__mesh=colored_labels_labels/CnP_contour_animation.gif

# %% [markdown]
# To watch video on Mac (local computer):
#
#     1. Download gif file
#     2. Run         ffmpeg -i CnP_contour_animation.gif \
#                    -vf "scale=ceil(iw/2)*2:ceil(ih/2)*2" \
#                    -movflags faststart -pix_fmt yuv420p \
#                     CnP_contour_animation.mp4
