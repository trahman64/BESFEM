# %% [markdown]
# -------------------------
# ## Compile Plots at All Timesteps for a Video

# %% [markdown]
# ### The below code is for a 3D Plot
#
# - Line #10: Change the directory of the results that will be plotted
# - Line #12: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #13: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize


# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260615_111721__nsteps=200001__mesh=colored_labels_labels"
mesh_file = os.path.join(result_dir, "pmesh_00000")
pattern = os.path.join(result_dir, "phE_[0-9]*")  # skip gif output
output_gif = os.path.join(result_dir, "phE_animation.gif")

# --- Load mesh once ---
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]

print(f"Found {len(files)} snapshots:")
# for f in files:
#     print("  ", os.path.basename(f))

# --- Setup figure once ---
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
# ax.set_title("Electrolyte Potential (phE)")
ax.view_init(elev=30, azim=45)

# norm = Normalize(vmin=0.0, vmax=1.0)
# levels = np.linspace(0, 1, 100) 

# Initialize dummy colorbar
dummy = ax.plot_trisurf(X, Y, np.zeros_like(X), cmap='viridis', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.6, pad=0.1)
dummy.remove()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load grid function
        x = mfem.GridFunction(mesh, fname)
        Z = x.GetDataArray()

        # Auto-compute color scale for this frame
        zmin, zmax = np.min(Z), np.max(Z)

        # Z = np.clip(Z, 0.0, 1.0)

        # zmin, zmax = np.min(Z), np.max(Z)

        # Redraw surface and colorbar
        ax.clear()
        # surf = ax.plot_trisurf(X, Y, Z, cmap='turbo', norm=norm)
        surf = ax.plot_trisurf(X, Y, Z, cmap='turbo')

        ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
        ax.set_title(f"Cathode Concentration (CnC) — timestep {timestep}")
        # ax.set_zlim(0.0, 1.0)
        # Update colorbar each frame
        cbar.ax.clear()
        fig.colorbar(surf, cax=cbar.ax)
        # cbar.ax.set_ylabel("Potential")

        # Save frame
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

os.remove("temp_frame.png")
print(f"✅ Animation saved to: {output_gif}")

# %% [markdown]
# ### The below code is for a 2D Contour Plot
#
# - Line #9: Change the directory of the results that will be plotted
# - Line #11: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #12: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize

# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260707_115008__nsteps=1__mesh=colored_labels_labels"
mesh_file = os.path.join(result_dir, "pmesh")
# mesh_file = os.path.join("../MSU_HPCC/pmesh")
pattern = os.path.join(result_dir, "CnP_total_[0-9]*")
output_gif = os.path.join(result_dir, "CnP_contour_animation.gif")

# --- Load mesh once --/
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Get vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]
# files = [f for f in files if get_timestep(f) % 1000 == 0]

print(f"Found {len(files)} snapshots:")

# --- Setup figure ---
fig, ax = plt.subplots(figsize=(7, 6))
ax.set_aspect('equal', adjustable='box')
ax.set_xticks([]); ax.set_yticks([])
plt.tight_layout()

# ✅ Fixed normalization and levels
norm = Normalize(vmin=0.0, vmax=0.09)
levels = np.linspace(0, 0.09, 100) 

# Dummy contour for fixed 0–1 colorbar
dummy = ax.tricontourf(X, Y, np.zeros_like(X), levels=levels, cmap='turbo', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.8, pad=0.02)
cbar.set_label("Lithium Concentration")
ax.clear()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load MFEM GridFunction data
        gf = mfem.GridFunction(mesh, fname)
        Z = gf.GetDataArray()

        Z = np.clip(Z, 0.0, 0.09) # Forcing values within [0, 1.0]

        ax.clear()
        cntr = ax.tricontourf(X, Y, Z, levels=levels, cmap='turbo', norm=norm)
        ax.set_aspect('equal', adjustable='box')
        ax.set_xticks([]); ax.set_yticks([])
        ax.set_title(f"Lithium Concentration — timestep {timestep}")

        # Save frame to temp file
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

# Clean up temporary frame
os.remove("temp_frame.png")
print(f"✅ 2D contour animation saved to: {output_gif}")
# Out:
# Found 169 snapshots:
# Rendering 1/169: timestep 0
# /tmp/ipykernel_1439091/3591400453.py:78: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   writer.append_data(imageio.imread(frame_path))
# Rendering 2/169: timestep 10000
# Rendering 3/169: timestep 20000
# Rendering 4/169: timestep 30000
# Rendering 5/169: timestep 40000
# Rendering 6/169: timestep 50000
# Rendering 7/169: timestep 60000
# Rendering 8/169: timestep 70000
# Rendering 9/169: timestep 80000
# Rendering 10/169: timestep 90000
# Rendering 11/169: timestep 100000
# Rendering 12/169: timestep 110000
# Rendering 13/169: timestep 120000
# Rendering 14/169: timestep 130000
# Rendering 15/169: timestep 140000
# Rendering 16/169: timestep 150000
# Rendering 17/169: timestep 160000
# Rendering 18/169: timestep 170000
# Rendering 19/169: timestep 180000
# Rendering 20/169: timestep 190000
# Rendering 21/169: timestep 200000
# Rendering 22/169: timestep 210000
# Rendering 23/169: timestep 220000
# Rendering 24/169: timestep 230000
# Rendering 25/169: timestep 240000
# Rendering 26/169: timestep 250000
# Rendering 27/169: timestep 260000
# Rendering 28/169: timestep 270000
# Rendering 29/169: timestep 280000
# Rendering 30/169: timestep 290000
# Rendering 31/169: timestep 300000
# Rendering 32/169: timestep 310000
# Rendering 33/169: timestep 320000
# Rendering 34/169: timestep 330000
# Rendering 35/169: timestep 340000
# Rendering 36/169: timestep 350000
# Rendering 37/169: timestep 360000
# Rendering 38/169: timestep 370000
# Rendering 39/169: timestep 380000
# Rendering 40/169: timestep 390000
# Rendering 41/169: timestep 400000
# Rendering 42/169: timestep 410000
# Rendering 43/169: timestep 420000
# Rendering 44/169: timestep 430000
# Rendering 45/169: timestep 440000
# Rendering 46/169: timestep 450000
# Rendering 47/169: timestep 460000
# Rendering 48/169: timestep 470000
# Rendering 49/169: timestep 480000
# Rendering 50/169: timestep 490000
# Rendering 51/169: timestep 500000
# Rendering 52/169: timestep 510000
# Rendering 53/169: timestep 520000
# Rendering 54/169: timestep 530000
# Rendering 55/169: timestep 540000
# Rendering 56/169: timestep 550000
# Rendering 57/169: timestep 560000
# Rendering 58/169: timestep 570000
# Rendering 59/169: timestep 580000
# Rendering 60/169: timestep 590000
# Rendering 61/169: timestep 600000
# Rendering 62/169: timestep 610000
# Rendering 63/169: timestep 620000
# Rendering 64/169: timestep 630000
# Rendering 65/169: timestep 640000
# Rendering 66/169: timestep 650000
# Rendering 67/169: timestep 660000
# Rendering 68/169: timestep 670000
# Rendering 69/169: timestep 680000
# Rendering 70/169: timestep 690000
# Rendering 71/169: timestep 700000
# Rendering 72/169: timestep 710000
# Rendering 73/169: timestep 720000
# Rendering 74/169: timestep 730000
# Rendering 75/169: timestep 740000
# Rendering 76/169: timestep 750000
# Rendering 77/169: timestep 760000
# Rendering 78/169: timestep 770000
# Rendering 79/169: timestep 780000
# Rendering 80/169: timestep 790000
# Rendering 81/169: timestep 800000
# Rendering 82/169: timestep 810000
# Rendering 83/169: timestep 820000
# Rendering 84/169: timestep 830000
# Rendering 85/169: timestep 840000
# Rendering 86/169: timestep 850000
# Rendering 87/169: timestep 860000
# Rendering 88/169: timestep 870000
# Rendering 89/169: timestep 880000
# Rendering 90/169: timestep 890000
# Rendering 91/169: timestep 900000
# Rendering 92/169: timestep 910000
# Rendering 93/169: timestep 920000
# Rendering 94/169: timestep 930000
# Rendering 95/169: timestep 940000
# Rendering 96/169: timestep 950000
# Rendering 97/169: timestep 960000
# Rendering 98/169: timestep 970000
# Rendering 99/169: timestep 980000
# Rendering 100/169: timestep 990000
# Rendering 101/169: timestep 1000000
# Rendering 102/169: timestep 1010000
# Rendering 103/169: timestep 1020000
# Rendering 104/169: timestep 1030000
# Rendering 105/169: timestep 1040000
# Rendering 106/169: timestep 1050000
# Rendering 107/169: timestep 1060000
# Rendering 108/169: timestep 1070000
# Rendering 109/169: timestep 1080000
# Rendering 110/169: timestep 1090000
# Rendering 111/169: timestep 1100000
# Rendering 112/169: timestep 1110000
# Rendering 113/169: timestep 1120000
# Rendering 114/169: timestep 1130000
# Rendering 115/169: timestep 1140000
# Rendering 116/169: timestep 1150000
# Rendering 117/169: timestep 1160000
# Rendering 118/169: timestep 1170000
# Rendering 119/169: timestep 1180000
# Rendering 120/169: timestep 1190000
# Rendering 121/169: timestep 1200000
# Rendering 122/169: timestep 1210000
# Rendering 123/169: timestep 1220000
# Rendering 124/169: timestep 1230000
# Rendering 125/169: timestep 1240000
# Rendering 126/169: timestep 1250000
# Rendering 127/169: timestep 1260000
# Rendering 128/169: timestep 1270000
# Rendering 129/169: timestep 1280000
# Rendering 130/169: timestep 1290000
# Rendering 131/169: timestep 1300000
# Rendering 132/169: timestep 1310000
# Rendering 133/169: timestep 1320000
# Rendering 134/169: timestep 1330000
# Rendering 135/169: timestep 1340000
# Rendering 136/169: timestep 1350000
# Rendering 137/169: timestep 1360000
# Rendering 138/169: timestep 1370000
# Rendering 139/169: timestep 1380000
# Rendering 140/169: timestep 1390000
# Rendering 141/169: timestep 1400000
# Rendering 142/169: timestep 1410000
# Rendering 143/169: timestep 1420000
# Rendering 144/169: timestep 1430000
# Rendering 145/169: timestep 1440000
# Rendering 146/169: timestep 1450000
# Rendering 147/169: timestep 1460000
# Rendering 148/169: timestep 1470000
# Rendering 149/169: timestep 1480000
# Rendering 150/169: timestep 1490000
# Rendering 151/169: timestep 1500000
# Rendering 152/169: timestep 1510000
# Rendering 153/169: timestep 1520000
# Rendering 154/169: timestep 1530000
# Rendering 155/169: timestep 1540000
# Rendering 156/169: timestep 1550000
# Rendering 157/169: timestep 1560000
# Rendering 158/169: timestep 1570000
# Rendering 159/169: timestep 1580000
# Rendering 160/169: timestep 1590000
# Rendering 161/169: timestep 1600000
# Rendering 162/169: timestep 1610000
# Rendering 163/169: timestep 1620000
# Rendering 164/169: timestep 1630000
# Rendering 165/169: timestep 1640000
# Rendering 166/169: timestep 1650000
# Rendering 167/169: timestep 1660000
# Rendering 168/169: timestep 1670000
# Rendering 169/169: timestep 1680000
# ✅ 2D contour animation saved to: ../outputs/Results/20260707_115008__nsteps=1__mesh=colored_labels_labels/CnP_contour_animation.gif

# %% [markdown]
# To watch video on Mac (local computer):
#
#     1. Download gif file
#     2. Run         ffmpeg -i CnP_contour_animation.gif \
#                    -vf "scale=ceil(iw/2)*2:ceil(ih/2)*2" \
#                    -movflags faststart -pix_fmt yuv420p \
#                     CnP_contour_animation.mp4
