# %% [markdown]
# -------------------------
# ## Compile Plots at All Timesteps for a Video

# %% [markdown]
# ### The below code is for a 3D Plot
#
# - Line #10: Change the directory of the results that will be plotted
# - Line #12: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #13: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize


# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260704_092935__nsteps=1__mesh=colored_labels_labels"
mesh_file = os.path.join(result_dir, "pmesh_00000")
pattern = os.path.join(result_dir, "phE_[0-9]*")  # skip gif output
output_gif = os.path.join(result_dir, "phE_animation.gif")

# --- Load mesh once ---
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]

print(f"Found {len(files)} snapshots:")
# for f in files:
#     print("  ", os.path.basename(f))

# --- Setup figure once ---
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
# ax.set_title("Electrolyte Potential (phE)")
ax.view_init(elev=30, azim=45)

# norm = Normalize(vmin=0.0, vmax=1.0)
# levels = np.linspace(0, 1, 100) 

# Initialize dummy colorbar
dummy = ax.plot_trisurf(X, Y, np.zeros_like(X), cmap='viridis', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.6, pad=0.1)
dummy.remove()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load grid function
        x = mfem.GridFunction(mesh, fname)
        Z = x.GetDataArray()

        # Auto-compute color scale for this frame
        zmin, zmax = np.min(Z), np.max(Z)

        # Z = np.clip(Z, 0.0, 1.0)

        # zmin, zmax = np.min(Z), np.max(Z)

        # Redraw surface and colorbar
        ax.clear()
        # surf = ax.plot_trisurf(X, Y, Z, cmap='turbo', norm=norm)
        surf = ax.plot_trisurf(X, Y, Z, cmap='turbo')

        ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
        ax.set_title(f"Cathode Concentration (CnC) — timestep {timestep}")
        # ax.set_zlim(0.0, 1.0)
        # Update colorbar each frame
        cbar.ax.clear()
        fig.colorbar(surf, cax=cbar.ax)
        # cbar.ax.set_ylabel("Potential")

        # Save frame
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

os.remove("temp_frame.png")
print(f"✅ Animation saved to: {output_gif}")

# %% [markdown]
# ### The below code is for a 2D Contour Plot
#
# - Line #9: Change the directory of the results that will be plotted
# - Line #11: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #12: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize

# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260708_111800__nsteps=1__mesh=colored_labels_labels"
mesh_file = os.path.join(result_dir, "pmesh")
# mesh_file = os.path.join("../MSU_HPCC/pmesh")
pattern = os.path.join(result_dir, "CnP_total_[0-9]*")
output_gif = os.path.join(result_dir, "CnP_contour_animation.gif")

# --- Load mesh once --/
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Get vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]
# files = [f for f in files if get_timestep(f) % 1000 == 0]

print(f"Found {len(files)} snapshots:")

# --- Setup figure ---
fig, ax = plt.subplots(figsize=(7, 6))
ax.set_aspect('equal', adjustable='box')
ax.set_xticks([]); ax.set_yticks([])
plt.tight_layout()

# ✅ Fixed normalization and levels
norm = Normalize(vmin=0.0, vmax=0.45)
levels = np.linspace(0, 0.45, 100) 

# Dummy contour for fixed 0–1 colorbar
dummy = ax.tricontourf(X, Y, np.zeros_like(X), levels=levels, cmap='turbo', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.8, pad=0.02)
cbar.set_label("Lithium Concentration")
ax.clear()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load MFEM GridFunction data
        gf = mfem.GridFunction(mesh, fname)
        Z = gf.GetDataArray()

        Z = np.clip(Z, 0.0, 0.45) # Forcing values within [0, 1.0]

        ax.clear()
        cntr = ax.tricontourf(X, Y, Z, levels=levels, cmap='turbo', norm=norm)
        ax.set_aspect('equal', adjustable='box')
        ax.set_xticks([]); ax.set_yticks([])
        ax.set_title(f"Lithium Concentration — timestep {timestep}")

        # Save frame to temp file
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

# Clean up temporary frame
os.remove("temp_frame.png")
print(f"✅ 2D contour animation saved to: {output_gif}")
# Out:
# Found 653 snapshots:
# Rendering 1/653: timestep 0
# /tmp/ipykernel_10255/1369251170.py:78: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   writer.append_data(imageio.imread(frame_path))
# Rendering 2/653: timestep 10000
# Rendering 3/653: timestep 20000
# Rendering 4/653: timestep 30000
# Rendering 5/653: timestep 40000
# Rendering 6/653: timestep 50000
# Rendering 7/653: timestep 60000
# Rendering 8/653: timestep 70000
# Rendering 9/653: timestep 80000
# Rendering 10/653: timestep 90000
# Rendering 11/653: timestep 100000
# Rendering 12/653: timestep 110000
# Rendering 13/653: timestep 120000
# Rendering 14/653: timestep 130000
# Rendering 15/653: timestep 140000
# Rendering 16/653: timestep 150000
# Rendering 17/653: timestep 160000
# Rendering 18/653: timestep 170000
# Rendering 19/653: timestep 180000
# Rendering 20/653: timestep 190000
# Rendering 21/653: timestep 200000
# Rendering 22/653: timestep 210000
# Rendering 23/653: timestep 220000
# Rendering 24/653: timestep 230000
# Rendering 25/653: timestep 240000
# Rendering 26/653: timestep 250000
# Rendering 27/653: timestep 260000
# Rendering 28/653: timestep 270000
# Rendering 29/653: timestep 280000
# Rendering 30/653: timestep 290000
# Rendering 31/653: timestep 300000
# Rendering 32/653: timestep 310000
# Rendering 33/653: timestep 320000
# Rendering 34/653: timestep 330000
# Rendering 35/653: timestep 340000
# Rendering 36/653: timestep 350000
# Rendering 37/653: timestep 360000
# Rendering 38/653: timestep 370000
# Rendering 39/653: timestep 380000
# Rendering 40/653: timestep 390000
# Rendering 41/653: timestep 400000
# Rendering 42/653: timestep 410000
# Rendering 43/653: timestep 420000
# Rendering 44/653: timestep 430000
# Rendering 45/653: timestep 440000
# Rendering 46/653: timestep 450000
# Rendering 47/653: timestep 460000
# Rendering 48/653: timestep 470000
# Rendering 49/653: timestep 480000
# Rendering 50/653: timestep 490000
# Rendering 51/653: timestep 500000
# Rendering 52/653: timestep 510000
# Rendering 53/653: timestep 520000
# Rendering 54/653: timestep 530000
# Rendering 55/653: timestep 540000
# Rendering 56/653: timestep 550000
# Rendering 57/653: timestep 560000
# Rendering 58/653: timestep 570000
# Rendering 59/653: timestep 580000
# Rendering 60/653: timestep 590000
# Rendering 61/653: timestep 600000
# Rendering 62/653: timestep 610000
# Rendering 63/653: timestep 620000
# Rendering 64/653: timestep 630000
# Rendering 65/653: timestep 640000
# Rendering 66/653: timestep 650000
# Rendering 67/653: timestep 660000
# Rendering 68/653: timestep 670000
# Rendering 69/653: timestep 680000
# Rendering 70/653: timestep 690000
# Rendering 71/653: timestep 700000
# Rendering 72/653: timestep 710000
# Rendering 73/653: timestep 720000
# Rendering 74/653: timestep 730000
# Rendering 75/653: timestep 740000
# Rendering 76/653: timestep 750000
# Rendering 77/653: timestep 760000
# Rendering 78/653: timestep 770000
# Rendering 79/653: timestep 780000
# Rendering 80/653: timestep 790000
# Rendering 81/653: timestep 800000
# Rendering 82/653: timestep 810000
# Rendering 83/653: timestep 820000
# Rendering 84/653: timestep 830000
# Rendering 85/653: timestep 840000
# Rendering 86/653: timestep 850000
# Rendering 87/653: timestep 860000
# Rendering 88/653: timestep 870000
# Rendering 89/653: timestep 880000
# Rendering 90/653: timestep 890000
# Rendering 91/653: timestep 900000
# Rendering 92/653: timestep 910000
# Rendering 93/653: timestep 920000
# Rendering 94/653: timestep 930000
# Rendering 95/653: timestep 940000
# Rendering 96/653: timestep 950000
# Rendering 97/653: timestep 960000
# Rendering 98/653: timestep 970000
# Rendering 99/653: timestep 980000
# Rendering 100/653: timestep 990000
# Rendering 101/653: timestep 1000000
# Rendering 102/653: timestep 1010000
# Rendering 103/653: timestep 1020000
# Rendering 104/653: timestep 1030000
# Rendering 105/653: timestep 1040000
# Rendering 106/653: timestep 1050000
# Rendering 107/653: timestep 1060000
# Rendering 108/653: timestep 1070000
# Rendering 109/653: timestep 1080000
# Rendering 110/653: timestep 1090000
# Rendering 111/653: timestep 1100000
# Rendering 112/653: timestep 1110000
# Rendering 113/653: timestep 1120000
# Rendering 114/653: timestep 1130000
# Rendering 115/653: timestep 1140000
# Rendering 116/653: timestep 1150000
# Rendering 117/653: timestep 1160000
# Rendering 118/653: timestep 1170000
# Rendering 119/653: timestep 1180000
# Rendering 120/653: timestep 1190000
# Rendering 121/653: timestep 1200000
# Rendering 122/653: timestep 1210000
# Rendering 123/653: timestep 1220000
# Rendering 124/653: timestep 1230000
# Rendering 125/653: timestep 1240000
# Rendering 126/653: timestep 1250000
# Rendering 127/653: timestep 1260000
# Rendering 128/653: timestep 1270000
# Rendering 129/653: timestep 1280000
# Rendering 130/653: timestep 1290000
# Rendering 131/653: timestep 1300000
# Rendering 132/653: timestep 1310000
# Rendering 133/653: timestep 1320000
# Rendering 134/653: timestep 1330000
# Rendering 135/653: timestep 1340000
# Rendering 136/653: timestep 1350000
# Rendering 137/653: timestep 1360000
# Rendering 138/653: timestep 1370000
# Rendering 139/653: timestep 1380000
# Rendering 140/653: timestep 1390000
# Rendering 141/653: timestep 1400000
# Rendering 142/653: timestep 1410000
# Rendering 143/653: timestep 1420000
# Rendering 144/653: timestep 1430000
# Rendering 145/653: timestep 1440000
# Rendering 146/653: timestep 1450000
# Rendering 147/653: timestep 1460000
# Rendering 148/653: timestep 1470000
# Rendering 149/653: timestep 1480000
# Rendering 150/653: timestep 1490000
# Rendering 151/653: timestep 1500000
# Rendering 152/653: timestep 1510000
# Rendering 153/653: timestep 1520000
# Rendering 154/653: timestep 1530000
# Rendering 155/653: timestep 1540000
# Rendering 156/653: timestep 1550000
# Rendering 157/653: timestep 1560000
# Rendering 158/653: timestep 1570000
# Rendering 159/653: timestep 1580000
# Rendering 160/653: timestep 1590000
# Rendering 161/653: timestep 1600000
# Rendering 162/653: timestep 1610000
# Rendering 163/653: timestep 1620000
# Rendering 164/653: timestep 1630000
# Rendering 165/653: timestep 1640000
# Rendering 166/653: timestep 1650000
# Rendering 167/653: timestep 1660000
# Rendering 168/653: timestep 1670000
# Rendering 169/653: timestep 1680000
# Rendering 170/653: timestep 1690000
# Rendering 171/653: timestep 1700000
# Rendering 172/653: timestep 1710000
# Rendering 173/653: timestep 1720000
# Rendering 174/653: timestep 1730000
# Rendering 175/653: timestep 1740000
# Rendering 176/653: timestep 1750000
# Rendering 177/653: timestep 1760000
# Rendering 178/653: timestep 1770000
# Rendering 179/653: timestep 1780000
# Rendering 180/653: timestep 1790000
# Rendering 181/653: timestep 1800000
# Rendering 182/653: timestep 1810000
# Rendering 183/653: timestep 1820000
# Rendering 184/653: timestep 1830000
# Rendering 185/653: timestep 1840000
# Rendering 186/653: timestep 1850000
# Rendering 187/653: timestep 1860000
# Rendering 188/653: timestep 1870000
# Rendering 189/653: timestep 1880000
# Rendering 190/653: timestep 1890000
# Rendering 191/653: timestep 1900000
# Rendering 192/653: timestep 1910000
# Rendering 193/653: timestep 1920000
# Rendering 194/653: timestep 1930000
# Rendering 195/653: timestep 1940000
# Rendering 196/653: timestep 1950000
# Rendering 197/653: timestep 1960000
# Rendering 198/653: timestep 1970000
# Rendering 199/653: timestep 1980000
# Rendering 200/653: timestep 1990000
# Rendering 201/653: timestep 2000000
# Rendering 202/653: timestep 2010000
# Rendering 203/653: timestep 2020000
# Rendering 204/653: timestep 2030000
# Rendering 205/653: timestep 2040000
# Rendering 206/653: timestep 2050000
# Rendering 207/653: timestep 2060000
# Rendering 208/653: timestep 2070000
# Rendering 209/653: timestep 2080000
# Rendering 210/653: timestep 2090000
# Rendering 211/653: timestep 2100000
# Rendering 212/653: timestep 2110000
# Rendering 213/653: timestep 2120000
# Rendering 214/653: timestep 2130000
# Rendering 215/653: timestep 2140000
# Rendering 216/653: timestep 2150000
# Rendering 217/653: timestep 2160000
# Rendering 218/653: timestep 2170000
# Rendering 219/653: timestep 2180000
# Rendering 220/653: timestep 2190000
# Rendering 221/653: timestep 2200000
# Rendering 222/653: timestep 2210000
# Rendering 223/653: timestep 2220000
# Rendering 224/653: timestep 2230000
# Rendering 225/653: timestep 2240000
# Rendering 226/653: timestep 2250000
# Rendering 490/653: timestep 4890000
# Rendering 491/653: timestep 4900000
# Rendering 492/653: timestep 4910000
# Rendering 493/653: timestep 4920000
# Rendering 494/653: timestep 4930000
# Rendering 495/653: timestep 4940000
# Rendering 496/653: timestep 4950000
# Rendering 497/653: timestep 4960000
# Rendering 498/653: timestep 4970000
# Rendering 499/653: timestep 4980000
# Rendering 500/653: timestep 4990000
# Rendering 501/653: timestep 5000000
# Rendering 502/653: timestep 5010000
# Rendering 503/653: timestep 5020000
# Rendering 504/653: timestep 5030000
# Rendering 505/653: timestep 5040000
# Rendering 506/653: timestep 5050000
# Rendering 507/653: timestep 5060000
# Rendering 508/653: timestep 5070000
# Rendering 509/653: timestep 5080000
# Rendering 510/653: timestep 5090000
# Rendering 511/653: timestep 5100000
# Rendering 512/653: timestep 5110000
# Rendering 513/653: timestep 5120000
# Rendering 514/653: timestep 5130000
# Rendering 515/653: timestep 5140000
# Rendering 516/653: timestep 5150000
# Rendering 517/653: timestep 5160000
# Rendering 518/653: timestep 5170000
# Rendering 519/653: timestep 5180000
# Rendering 520/653: timestep 5190000
# Rendering 521/653: timestep 5200000
# Rendering 522/653: timestep 5210000
# Rendering 523/653: timestep 5220000
# Rendering 524/653: timestep 5230000
# Rendering 525/653: timestep 5240000
# Rendering 526/653: timestep 5250000
# Rendering 527/653: timestep 5260000
# Rendering 528/653: timestep 5270000
# Rendering 529/653: timestep 5280000
# Rendering 530/653: timestep 5290000
# Rendering 531/653: timestep 5300000
# Rendering 532/653: timestep 5310000
# Rendering 533/653: timestep 5320000
# Rendering 534/653: timestep 5330000
# Rendering 535/653: timestep 5340000
# Rendering 536/653: timestep 5350000
# Rendering 537/653: timestep 5360000
# Rendering 538/653: timestep 5370000
# Rendering 539/653: timestep 5380000
# Rendering 540/653: timestep 5390000
# Rendering 541/653: timestep 5400000
# Rendering 542/653: timestep 5410000
# Rendering 543/653: timestep 5420000
# Rendering 544/653: timestep 5430000
# Rendering 545/653: timestep 5440000
# Rendering 546/653: timestep 5450000
# Rendering 547/653: timestep 5460000
# Rendering 548/653: timestep 5470000
# Rendering 549/653: timestep 5480000
# Rendering 550/653: timestep 5490000
# Rendering 551/653: timestep 5500000
# Rendering 552/653: timestep 5510000
# Rendering 553/653: timestep 5520000
# Rendering 554/653: timestep 5530000
# Rendering 555/653: timestep 5540000
# Rendering 556/653: timestep 5550000
# Rendering 557/653: timestep 5560000
# Rendering 558/653: timestep 5570000
# Rendering 559/653: timestep 5580000
# Rendering 560/653: timestep 5590000
# Rendering 561/653: timestep 5600000
# Rendering 562/653: timestep 5610000
# Rendering 563/653: timestep 5620000
# Rendering 564/653: timestep 5630000
# Rendering 565/653: timestep 5640000
# Rendering 566/653: timestep 5650000
# Rendering 567/653: timestep 5660000
# Rendering 568/653: timestep 5670000
# Rendering 569/653: timestep 5680000
# Rendering 570/653: timestep 5690000
# Rendering 571/653: timestep 5700000
# Rendering 572/653: timestep 5710000
# Rendering 573/653: timestep 5720000
# Rendering 574/653: timestep 5730000
# Rendering 575/653: timestep 5740000
# Rendering 576/653: timestep 5750000
# Rendering 577/653: timestep 5760000
# Rendering 578/653: timestep 5770000
# Rendering 579/653: timestep 5780000
# Rendering 580/653: timestep 5790000
# Rendering 581/653: timestep 5800000
# Rendering 582/653: timestep 5810000
# Rendering 583/653: timestep 5820000
# Rendering 584/653: timestep 5830000
# Rendering 585/653: timestep 5840000
# Rendering 586/653: timestep 5850000
# Rendering 587/653: timestep 5860000
# Rendering 588/653: timestep 5870000
# Rendering 589/653: timestep 5880000
# Rendering 590/653: timestep 5890000
# Rendering 591/653: timestep 5900000
# Rendering 592/653: timestep 5910000
# Rendering 593/653: timestep 5920000
# Rendering 594/653: timestep 5930000
# Rendering 595/653: timestep 5940000
# Rendering 596/653: timestep 5950000
# Rendering 597/653: timestep 5960000
# Rendering 598/653: timestep 5970000
# Rendering 599/653: timestep 5980000
# Rendering 600/653: timestep 5990000
# Rendering 601/653: timestep 6000000
# Rendering 602/653: timestep 6010000
# Rendering 603/653: timestep 6020000
# Rendering 604/653: timestep 6030000
# Rendering 605/653: timestep 6040000
# Rendering 606/653: timestep 6050000
# Rendering 607/653: timestep 6060000
# Rendering 608/653: timestep 6070000
# Rendering 609/653: timestep 6080000
# Rendering 610/653: timestep 6090000
# Rendering 611/653: timestep 6100000
# Rendering 612/653: timestep 6110000
# Rendering 613/653: timestep 6120000
# Rendering 614/653: timestep 6130000
# Rendering 615/653: timestep 6140000
# Rendering 616/653: timestep 6150000
# Rendering 617/653: timestep 6160000
# Rendering 618/653: timestep 6170000
# Rendering 619/653: timestep 6180000
# Rendering 620/653: timestep 6190000
# Rendering 621/653: timestep 6200000
# Rendering 622/653: timestep 6210000
# Rendering 623/653: timestep 6220000
# Rendering 624/653: timestep 6230000
# Rendering 625/653: timestep 6240000
# Rendering 626/653: timestep 6250000
# Rendering 627/653: timestep 6260000
# Rendering 628/653: timestep 6270000
# Rendering 629/653: timestep 6280000
# Rendering 630/653: timestep 6290000
# Rendering 631/653: timestep 6300000
# Rendering 632/653: timestep 6310000
# Rendering 633/653: timestep 6320000
# Rendering 634/653: timestep 6330000
# Rendering 635/653: timestep 6340000
# Rendering 636/653: timestep 6350000
# Rendering 637/653: timestep 6360000
# Rendering 638/653: timestep 6370000
# Rendering 639/653: timestep 6380000
# Rendering 640/653: timestep 6390000
# Rendering 641/653: timestep 6400000
# Rendering 642/653: timestep 6410000
# Rendering 643/653: timestep 6420000
# Rendering 644/653: timestep 6430000
# Rendering 645/653: timestep 6440000
# Rendering 646/653: timestep 6450000
# Rendering 647/653: timestep 6460000
# Rendering 648/653: timestep 6470000
# Rendering 649/653: timestep 6480000
# Rendering 650/653: timestep 6490000
# Rendering 651/653: timestep 6500000
# Rendering 652/653: timestep 6510000
# Rendering 653/653: timestep 6520000
# ✅ 2D contour animation saved to: ../outputs/Results/20260708_111800__nsteps=1__mesh=colored_labels_labels/CnP_contour_animation.gif

# %% [markdown]
# To watch video on Mac (local computer):
#
#     1. Download gif file
#     2. Run         ffmpeg -i CnP_contour_animation.gif \
#                    -vf "scale=ceil(iw/2)*2:ceil(ih/2)*2" \
#                    -movflags faststart -pix_fmt yuv420p \
#                     CnP_contour_animation.mp4
