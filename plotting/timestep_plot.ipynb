# %% [markdown]
# -------------------------
# ## Compile Plots at All Timesteps for a Video

# %% [markdown]
# ### The below code is for a 3D Plot
#
# - Line #10: Change the directory of the results that will be plotted
# - Line #12: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #13: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize


# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260615_111721__nsteps=200001__mesh=colored_labels_labels"
mesh_file = os.path.join(result_dir, "pmesh_00000")
pattern = os.path.join(result_dir, "phE_[0-9]*")  # skip gif output
output_gif = os.path.join(result_dir, "phE_animation.gif")

# --- Load mesh once ---
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]

print(f"Found {len(files)} snapshots:")
# for f in files:
#     print("  ", os.path.basename(f))

# --- Setup figure once ---
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
# ax.set_title("Electrolyte Potential (phE)")
ax.view_init(elev=30, azim=45)

# norm = Normalize(vmin=0.0, vmax=1.0)
# levels = np.linspace(0, 1, 100) 

# Initialize dummy colorbar
dummy = ax.plot_trisurf(X, Y, np.zeros_like(X), cmap='viridis', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.6, pad=0.1)
dummy.remove()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load grid function
        x = mfem.GridFunction(mesh, fname)
        Z = x.GetDataArray()

        # Auto-compute color scale for this frame
        zmin, zmax = np.min(Z), np.max(Z)

        # Z = np.clip(Z, 0.0, 1.0)

        # zmin, zmax = np.min(Z), np.max(Z)

        # Redraw surface and colorbar
        ax.clear()
        # surf = ax.plot_trisurf(X, Y, Z, cmap='turbo', norm=norm)
        surf = ax.plot_trisurf(X, Y, Z, cmap='turbo')

        ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
        ax.set_title(f"Cathode Concentration (CnC) — timestep {timestep}")
        # ax.set_zlim(0.0, 1.0)
        # Update colorbar each frame
        cbar.ax.clear()
        fig.colorbar(surf, cax=cbar.ax)
        # cbar.ax.set_ylabel("Potential")

        # Save frame
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

os.remove("temp_frame.png")
print(f"✅ Animation saved to: {output_gif}")

# %% [markdown]
# ### The below code is for a 2D Contour Plot
#
# - Line #9: Change the directory of the results that will be plotted
# - Line #11: Change the name of the variable that will be plotted (ex: CnP for Concentration Particle)
# - Line #12: Change the name of the save gif

# %%
import mfem.ser as mfem
import numpy as np
import matplotlib.pyplot as plt
import imageio
import glob, os
from matplotlib.colors import Normalize

# --- USER SETTINGS ---
result_dir = "../outputs/Results/20260618_120157__nsteps=2000001__mesh=colored_labels_labels"
mesh_file = os.path.join(result_dir, "pmesh")
# mesh_file = os.path.join("../MSU_HPCC/pmesh")
pattern = os.path.join(result_dir, "CnP_total_[0-9]*")
output_gif = os.path.join(result_dir, "CnP_contour_animation.gif")

# --- Load mesh once --/
mesh = mfem.Mesh()
mesh.Load(mesh_file)

# Get vertex coordinates
vertices = mesh.GetVertexArray()
ar = np.array(vertices)
X, Y = ar[:, 0], ar[:, 1]

# --- Gather snapshot files ---
files = sorted(glob.glob(pattern))

# Sort numerically by timestep, not lexicographically
def get_timestep(fname):
    try:
        return int(os.path.basename(fname).split("_")[-1])
    except ValueError:
        return -1

files = sorted(files, key=get_timestep)
files = [f for f in files if os.path.basename(f).split("_")[-1].isdigit()]
# files = [f for f in files if get_timestep(f) % 1000 == 0]

print(f"Found {len(files)} snapshots:")

# --- Setup figure ---
fig, ax = plt.subplots(figsize=(7, 6))
ax.set_aspect('equal', adjustable='box')
ax.set_xticks([]); ax.set_yticks([])
plt.tight_layout()

# ✅ Fixed normalization and levels
norm = Normalize(vmin=0.0, vmax=1.0)
levels = np.linspace(0, 1.0, 100) 

# Dummy contour for fixed 0–1 colorbar
dummy = ax.tricontourf(X, Y, np.zeros_like(X), levels=levels, cmap='turbo', norm=norm)
cbar = fig.colorbar(dummy, ax=ax, shrink=0.8, pad=0.02)
cbar.set_label("Lithium Concentration")
ax.clear()

# --- Create GIF writer ---
with imageio.get_writer(output_gif, mode='I', fps=5) as writer:
    for i, fname in enumerate(files):
        step_str = os.path.basename(fname).split("_")[-1]
        timestep = int(step_str)
        print(f"Rendering {i+1}/{len(files)}: timestep {timestep}")

        # Load MFEM GridFunction data
        gf = mfem.GridFunction(mesh, fname)
        Z = gf.GetDataArray()

        Z = np.clip(Z, 0.0, 1.0) # Forcing values within [0, 1.0]

        ax.clear()
        cntr = ax.tricontourf(X, Y, Z, levels=levels, cmap='turbo', norm=norm)
        ax.set_aspect('equal', adjustable='box')
        ax.set_xticks([]); ax.set_yticks([])
        ax.set_title(f"Lithium Concentration — timestep {timestep}")

        # Save frame to temp file
        frame_path = "temp_frame.png"
        plt.savefig(frame_path, dpi=100, bbox_inches='tight')
        writer.append_data(imageio.imread(frame_path))

# Clean up temporary frame
os.remove("temp_frame.png")
print(f"✅ 2D contour animation saved to: {output_gif}")
# Out:
# Found 801 snapshots:
# Rendering 1/801: timestep 0
# /tmp/ipykernel_3302536/1851632217.py:78: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   writer.append_data(imageio.imread(frame_path))
# Rendering 2/801: timestep 5000
# Rendering 3/801: timestep 10000
# Rendering 4/801: timestep 15000
# Rendering 5/801: timestep 20000
# Rendering 6/801: timestep 25000
# Rendering 7/801: timestep 30000
# Rendering 8/801: timestep 35000
# Rendering 9/801: timestep 40000
# Rendering 10/801: timestep 45000
# Rendering 11/801: timestep 50000
# Rendering 12/801: timestep 55000
# Rendering 13/801: timestep 60000
# Rendering 14/801: timestep 65000
# Rendering 15/801: timestep 70000
# Rendering 16/801: timestep 75000
# Rendering 17/801: timestep 80000
# Rendering 18/801: timestep 85000
# Rendering 19/801: timestep 90000
# Rendering 20/801: timestep 95000
# Rendering 21/801: timestep 100000
# Rendering 22/801: timestep 105000
# Rendering 23/801: timestep 110000
# Rendering 24/801: timestep 115000
# Rendering 25/801: timestep 120000
# Rendering 26/801: timestep 125000
# Rendering 27/801: timestep 130000
# Rendering 28/801: timestep 135000
# Rendering 29/801: timestep 140000
# Rendering 30/801: timestep 145000
# Rendering 31/801: timestep 150000
# Rendering 32/801: timestep 155000
# Rendering 33/801: timestep 160000
# Rendering 34/801: timestep 165000
# Rendering 35/801: timestep 170000
# Rendering 36/801: timestep 175000
# Rendering 37/801: timestep 180000
# Rendering 38/801: timestep 185000
# Rendering 39/801: timestep 190000
# Rendering 40/801: timestep 195000
# Rendering 41/801: timestep 200000
# Rendering 42/801: timestep 205000
# Rendering 43/801: timestep 210000
# Rendering 44/801: timestep 215000
# Rendering 45/801: timestep 220000
# Rendering 46/801: timestep 225000
# Rendering 47/801: timestep 230000
# Rendering 48/801: timestep 235000
# Rendering 49/801: timestep 240000
# Rendering 50/801: timestep 245000
# Rendering 51/801: timestep 250000
# Rendering 52/801: timestep 255000
# Rendering 53/801: timestep 260000
# Rendering 54/801: timestep 265000
# Rendering 55/801: timestep 270000
# Rendering 56/801: timestep 275000
# Rendering 57/801: timestep 280000
# Rendering 58/801: timestep 285000
# Rendering 59/801: timestep 290000
# Rendering 60/801: timestep 295000
# Rendering 61/801: timestep 300000
# Rendering 62/801: timestep 305000
# Rendering 63/801: timestep 310000
# Rendering 64/801: timestep 315000
# Rendering 65/801: timestep 320000
# Rendering 66/801: timestep 325000
# Rendering 67/801: timestep 330000
# Rendering 68/801: timestep 335000
# Rendering 69/801: timestep 340000
# Rendering 70/801: timestep 345000
# Rendering 71/801: timestep 350000
# Rendering 732/801: timestep 3655000
# Rendering 733/801: timestep 3660000
# Rendering 734/801: timestep 3665000
# Rendering 735/801: timestep 3670000
# Rendering 736/801: timestep 3675000
# Rendering 737/801: timestep 3680000
# Rendering 738/801: timestep 3685000
# Rendering 739/801: timestep 3690000
# Rendering 740/801: timestep 3695000
# Rendering 741/801: timestep 3700000
# Rendering 742/801: timestep 3705000
# Rendering 743/801: timestep 3710000
# Rendering 744/801: timestep 3715000
# Rendering 745/801: timestep 3720000
# Rendering 746/801: timestep 3725000
# Rendering 747/801: timestep 3730000
# Rendering 748/801: timestep 3735000
# Rendering 749/801: timestep 3740000
# Rendering 750/801: timestep 3745000
# Rendering 751/801: timestep 3750000
# Rendering 752/801: timestep 3755000
# Rendering 753/801: timestep 3760000
# Rendering 754/801: timestep 3765000
# Rendering 755/801: timestep 3770000
# Rendering 756/801: timestep 3775000
# Rendering 757/801: timestep 3780000
# Rendering 758/801: timestep 3785000
# Rendering 759/801: timestep 3790000
# Rendering 760/801: timestep 3795000
# Rendering 761/801: timestep 3800000
# Rendering 762/801: timestep 3805000
# Rendering 763/801: timestep 3810000
# Rendering 764/801: timestep 3815000
# Rendering 765/801: timestep 3820000
# Rendering 766/801: timestep 3825000
# Rendering 767/801: timestep 3830000
# Rendering 768/801: timestep 3835000
# Rendering 769/801: timestep 3840000
# Rendering 770/801: timestep 3845000
# Rendering 771/801: timestep 3850000
# Rendering 772/801: timestep 3855000
# Rendering 773/801: timestep 3860000
# Rendering 774/801: timestep 3865000
# Rendering 775/801: timestep 3870000
# Rendering 776/801: timestep 3875000
# Rendering 777/801: timestep 3880000
# Rendering 778/801: timestep 3885000
# Rendering 779/801: timestep 3890000
# Rendering 780/801: timestep 3895000
# Rendering 781/801: timestep 3900000
# Rendering 782/801: timestep 3905000
# Rendering 783/801: timestep 3910000
# Rendering 784/801: timestep 3915000
# Rendering 785/801: timestep 3920000
# Rendering 786/801: timestep 3925000
# Rendering 787/801: timestep 3930000
# Rendering 788/801: timestep 3935000
# Rendering 789/801: timestep 3940000
# Rendering 790/801: timestep 3945000
# Rendering 791/801: timestep 3950000
# Rendering 792/801: timestep 3955000
# Rendering 793/801: timestep 3960000
# Rendering 794/801: timestep 3965000
# Rendering 795/801: timestep 3970000
# Rendering 796/801: timestep 3975000
# Rendering 797/801: timestep 3980000
# Rendering 798/801: timestep 3985000
# Rendering 799/801: timestep 3990000
# Rendering 800/801: timestep 3995000
# Rendering 801/801: timestep 4000000
# ✅ 2D contour animation saved to: ../outputs/Results/20260618_144436__nsteps=4000001__mesh=colored_labels_labels/CnP_contour_animation.gif

# %% [markdown]
# To watch video on Mac (local computer):
#
#     1. Download gif file
#     2. Run         ffmpeg -i CnP_contour_animation.gif \
#                    -vf "scale=ceil(iw/2)*2:ceil(ih/2)*2" \
#                    -movflags faststart -pix_fmt yuv420p \
#                     CnP_contour_animation.mp4
