# %% [markdown]
# --------------------------
#
# ## Plotting Using MFEM's PyGLViS
#
# More information: https://github.com/GLVis/pyglvis

# %%
# Pip installs pyglvis (and pymfem) if in a colab notebook. Can comment out if not required
# %pip install --quiet mfem==4.8.0 glvis
from glvis import glvis, GlvisData
import mfem.ser as mfem
import numpy as np
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
mesh = mfem.Mesh()
mesh.Load("../bin/pmesh")
x = mfem.GridFunction(mesh,"../bin/psi")

mesh.Load("../outputs/Results/20260707_135648__nsteps=-1__mesh=colored_labels_labels/pmesh")
x = mfem.GridFunction(mesh, "../outputs/Results/20260707_135648__nsteps=-1__mesh=colored_labels_labels/psi")

# mesh.Load("../outputs/Results/20260615_111721__nsteps=200001__mesh=colored_labels_labels/pmesh_00000")
# mesh.Load("../MSU_HPCC/pmesh")
# x = mfem.GridFunction(mesh, "../outputs/Results/20260615_115122__nsteps=200001__mesh=colored_labels_labels/CnP_total_135000")

# %%
# Plot the mesh + solution (all GLVis keys and mouse commands work)
g = glvis((mesh, x))
g
